# %%
# imports for the project

import pandas as pd
from decouple import config
from ibm_watsonx_ai import APIClient
from ibm_watsonx_ai import Credentials
from ibm_watsonx_ai.foundation_models import ModelInference
from dotenv import load_dotenv
from sklearn.metrics import classification_report 
from tqdm import tqdm
from ibm_watsonx_ai.foundation_models.schema import TextGenParameters

# %%
import os
print(os.path.exists(".env"))
# Out:
# True

# %%
# Load .env file
load_dotenv()

# Get the API key
WX_API_KEY = os.getenv('WX_API_KEY')
WX_PROJECT_ID = os.getenv('WX_Project_ID')

if WX_API_KEY:
    print("API Key Loaded Successfully")
else:
    print("API Key Not Found! Check your .env file.")

WX_API_URL = "https://us-south.ml.cloud.ibm.com"
# Out:
# API Key Loaded Successfully

# %%
from langchain_ibm import WatsonxLLM
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams


llm = WatsonxLLM(

        model_id= "ibm/granite-3-8b-instruct",
        url=WX_API_URL,
        apikey=WX_API_KEY,
        project_id=WX_PROJECT_ID,

        params={
            GenParams.DECODING_METHOD: "greedy",
            GenParams.TEMPERATURE: 0,
            GenParams.MIN_NEW_TOKENS: 5,
            GenParams.MAX_NEW_TOKENS: 1_000,
            GenParams.REPETITION_PENALTY:1.2
        }

)

# %%
from langchain_core.documents import Document
from langchain_community.document_loaders import TextLoader


document = TextLoader(r"C:\Users\charl\Documents\CBS\Code Projects_Python\AIML25\AIML25_Project\consolidated.md").load()[0]
document.metadata
# Out:
# {'source': 'C:\\Users\\charl\\Documents\\CBS\\Code Projects_Python\\AIML25\\AIML25_Project\\consolidated.md'}

# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter

# %%
# Step 1: Structural split by headers
from langchain_text_splitters import RecursiveCharacterTextSplitter


headers_to_split_on = [("#", "Header 1"), ("##", "Header 2"), ("###", "Header 3")]
markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
header_chunks = markdown_splitter.split_text(document.page_content)

# Step 2: Token-based split inside each header chunk
token_splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=50)

# Step 3: Apply token-based split to each chunk
final_chunks = []
for chunk in header_chunks:
    sub_chunks = token_splitter.split_text(chunk.page_content)
    for sub_chunk in sub_chunks:
        final_chunks.append(Document(page_content=sub_chunk, metadata=chunk.metadata))

# %%
filtered_chunks = []
for chunk in final_chunks:
    is_footer = chunk.metadata.get("Header 3") == "Page Footer"
    is_mostly_link_or_boilerplate = (
        len(chunk.page_content.strip()) < 150 or  # too short
        chunk.page_content.count("http") > 1      # mostly links
    )

    if is_footer and is_mostly_link_or_boilerplate:
        continue  # Skip useless footers
    filtered_chunks.append(chunk)

# %%
for i, chunk in enumerate(final_chunks):
    if "574,99 €" in chunk.page_content:
        print(f"FOUND in chunk {i}:\n{chunk.page_content}\n")
# Out:
# FOUND in chunk 8:
# 574,99 € <!-- text, from page 0 (l=0.089,t=0.882,r=0.251,b=0.907), with ID 75d48396-2c0c-44cb-9f01-3c0dc89b119b -->
#
# FOUND in chunk 565:
# - **Price**: 574,99 €
# - **Includes**: MwSt. (VAT)
# - **Delivery**: kostenlose Lieferung ab 50 € (free delivery from 50 €) <!-- text, from page 0 (l=0.087,t=0.882,r=0.404,b=0.932), with ID 6d1d2a2d-6b64-434d-94a7-941377fdaf41 -->

# %%
filtered_chunks
# Out:
# [Document(metadata={'Header 2': 'Page Header'}, page_content='The image displays the logo of Kärcher, a company known for its cleaning equipment. The logo consists of the word "KÄRCHER" in bold, black uppercase letters. Below the text, there is a yellow horizontal bar. The background is white, providing contrast to the black text and yellow bar. <!--'),
#  Document(metadata={'Header 2': 'Page Header'}, page_content='contrast to the black text and yellow bar. <!-- page_header, from page 0 (l=0.062,t=0.031,r=0.223,b=0.063), with ID b870019e-e912-44a9-b958-687bea146dcc -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text'}, page_content='Für mehr Power: K 7 Power Flex Home Hochdruckreiniger mit PremiumFlex-Schlauch, G 180 Q-Pistole für hartnäckige Verschmutzungen rund ums Haus. Inkl. Home Kit. <!-- text, from page 0 (l=0.064,t=0.121,r=0.850,b=0.148), with ID 9ee6b603-ece9-4526-85da-a653334c1b50 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='The image displays a Kärcher K7 pressure washer set, which includes several components:'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='- **Main Unit**: The central piece is the Kärcher K7 pressure washer, characterized by its yellow and black color scheme. It has a sturdy handle for easy maneuverability and large wheels for transport. The model name "K7" is prominently displayed on the side.  \n- **Accessories**:'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='- **Accessories**:\n- **Surface Cleaner**: A circular attachment designed for cleaning flat surfaces. It is also yellow and black, matching the main unit.'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='- **Spray Lances**: Two different spray lances are included, each designed for specific cleaning tasks. They are black and attach to the main unit.\n- **Detergent Bottle**: A bottle labeled "Stone & Facade" is included, indicating it is a cleaning solution specifically for stone surfaces.'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='This set is designed for high-performance cleaning, suitable for various outdoor surfaces. <!-- figure, from page 0 (l=0.065,t=0.192,r=0.934,b=0.866), with ID fc9582c1-5cdc-43a2-8037-20ccf547f2f3 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Price'}, page_content='574,99 € <!-- text, from page 0 (l=0.089,t=0.882,r=0.251,b=0.907), with ID 75d48396-2c0c-44cb-9f01-3c0dc89b119b -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text Content'}, page_content='inkl. MwSt. - kostenlose Lieferung ab 50 € <!-- text, from page 0 (l=0.087,t=0.920,r=0.404,b=0.932), with ID d3e3ba9e-b11c-40d5-a572-128adb790ab3 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Header'}, page_content='26/04/2025, 18:05 <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.149,b=0.027), with ID a9c01ec5-8216-4d33-b700-304b87615ff0 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Number'}, page_content='1/14 <!-- page_number, from page 0 (l=0.932,t=0.972,r=0.959,b=0.980), with ID f4d8d62b-3ec7-4a80-99b2-c277a43d2b65 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Footer'}, page_content='[https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-home-13173020.html](https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-home-13173020.html) <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.626,b=0.981), with ID 16b7a75f-5c86-4379-9589-0da38032f67b -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'K 7 Power Flex Home | Kärcher'}, page_content='This is a page header indicating the product name "K 7 Power Flex Home" by the brand "Kärcher". <!-- page_header, from page 0 (l=0.484,t=0.019,r=0.674,b=0.028), with ID 1201169f-a536-4cbd-bf00-67d475a04056 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Header'}, page_content='Date: 26/04/2025, 18:05 <!-- page_header, from page 1 (l=0.039,t=0.019,r=0.147,b=0.027), with ID 1188b5b6-2032-46f8-aed1-78b5abfe5687 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'K 7 Power Flex Home | Kärcher'}, page_content='This is a page header indicating the product name "K 7 Power Flex Home" by the brand "Kärcher". <!-- page_header, from page 1 (l=0.484,t=0.019,r=0.672,b=0.028), with ID 5d635fb4-2165-4d6b-8c67-5520e3678ea6 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text Information'}, page_content='- Lieferbar in: 2-3 Werktagen\n- Bestellnummer: 1.317-302.0 <!-- key_value, from page 1 (l=0.087,t=0.037,r=0.300,b=0.069), with ID ffd326cb-94fb-4daf-9572-1ddaeda87ac1 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Händler Suche'}, page_content='- **Ort oder PLZ**: [Input field]'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Händler Suche', 'Header 3': 'Bewertung'}, page_content='- **Rating**: ★★★★★ 4.7 (48)\n- **Option**: Jetzt Produkt bewerten'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Händler Suche', 'Header 3': 'Funktionen'}, page_content='- **Produkt vergleichen**: [Dropdown or expandable section]'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Händler Suche', 'Header 3': 'Hilfe'}, page_content='- **Benötigen Sie Hilfe?**\n- **Hotline**: +49 7195 903 0 <!-- form, from page 1 (l=0.087,t=0.113,r=0.500,b=0.334), with ID 746c2ba4-26f6-43f8-8dea-a45eb9d7ace0 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text'}, page_content='Mit dem Hochdruckreiniger K 7 Power Flex Home lässt sich jede Oberfläche mit passendem Druck reinigen. Um den richtigen Druck zu finden, unterstützt der in der Kärcher Home & Garden App integrierte Anwendungsberater den Nutzer mit praktischen Tipps zu jeder Reinigungssituation und jedem'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text'}, page_content='Tipps zu jeder Reinigungssituation und jedem Reinigungsobjekt – für perfekte Reinigungsergebnisse. Der K 7 Power Flex Home ist mit einem wassergekühlten Motor ausgestattet und wurde gebaut für häufige Reinigungseinsätze und starke Verschmutzungen. Das reichhaltige Ausstattungspaket reicht von einer'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text'}, page_content='reichhaltige Ausstattungspaket reicht von einer Pistole mit praktischem Quick Connect-Anschluss über einen PremiumFlex-Hochdruckschlauch und einen zuverlässigen Wasserfilter zum Schutz der Pumpe bis zu einem Vario Power-Strahlrohr (VPS) sowie einem Dreckfräser mit rotierendem Punktstrahl. Die'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text'}, page_content="Dreckfräser mit rotierendem Punktstrahl. Die Druckeinstellung am VPS lässt sich buchstäblich im Handumdrehen variieren, und der Dreckfräser macht selbst hartnäckigsten Verschmutzungen den Garaus. Weitere Ausstattungsdetails sind das Plug 'n' Clean-Reinigungssystem, der Aluminium-Teleskopgriff und"),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text'}, page_content='der Aluminium-Teleskopgriff und die Parkposition für griffbereites Zubehör. Inklusive Home Kit mit Flächenreiniger T 7 und 1 Liter Stein- und Fassadenreiniger. <!-- text, from page 1 (l=0.064,t=0.445,r=0.921,b=0.623), with ID 3d2de5d5-6846-4402-84fd-a69366979781 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Footer'}, page_content='[https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-home-13173020.html](https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-home-13173020.html) <!-- page_footer, from page 1 (l=0.039,t=0.972,r=0.626,b=0.981), with ID 02328868-e260-4921-8215-f1876ab2b6ff -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Header'}, page_content='26/04/2025, 18:05 <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.147,b=0.027), with ID a717f9f8-a503-4b5c-a8a9-392061d60639 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'K 7 Power Flex Home | Kärcher'}, page_content='This is a page header indicating the product name "K 7 Power Flex Home" by the brand "Kärcher". <!-- page_header, from page 0 (l=0.484,t=0.019,r=0.674,b=0.027), with ID 31f6d5dd-c8f4-4114-b96d-86392a41d12f -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Figure Description'}, page_content='The image shows a hand placing a container into a slot on a Kärcher cleaning device. The container is labeled with the text "BRING BACK THE WOW" and "CLEAN MAINTAIN." The Kärcher logo is visible on the container. The device has a black and yellow color scheme, typical of Kärcher products. The hand'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Figure Description'}, page_content='scheme, typical of Kärcher products. The hand is positioned to insert the container into the designated area on the device, which appears to be part of a cleaning system.'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Figure Description'}, page_content='Below the image, there is a caption in German: "Plug \'n\' Clean – das Kärcher Reinigungsmittelsystem," which translates to "Plug \'n\' Clean – the Kärcher cleaning agent system." This suggests that the system allows for easy insertion and use of cleaning agents with the device. <!-- figure, from page'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Figure Description'}, page_content='agents with the device. <!-- figure, from page 0 (l=0.062,t=0.031,r=0.935,b=0.663), with ID fa5a0cb8-4b7b-44d9-bd2e-edc6238b62ee -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Schnell, einfach, komfortabel'}, page_content="Dank Plug 'n' Clean lässt sich das Reinigungsmittel mit nur einem Handgriff bequem austauschen. <!-- text, from page 0 (l=0.064,t=0.669,r=0.914,b=0.694), with ID 91590b46-4a2a-46b4-ad17-7138cc7e363b -->"),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Überragende Leistung'}, page_content='- Der wassergekühlte Motor besticht durch seine besondere Langlebigkeit und Leistungsfähigkeit. <!-- text, from page 0 (l=0.081,t=0.726,r=0.818,b=0.767), with ID 73bd32d5-b715-4fab-b17c-d2bcfa5bbc1b -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Technische Daten'}, page_content='- **Stromart (V/Hz)**: 230 / 50\n- **Druck (bar/MPa)**: 20 - max. 180 / 2 - max. 18 <!-- text, from page 0 (l=0.064,t=0.853,r=0.740,b=0.939), with ID 9a59049a-e149-4a29-936e-4e9f3287c688 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Footer'}, page_content='https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-home-13173020.html <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.626,b=0.981), with ID cde33419-e0e8-43b9-80bd-91873ec28e1d -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Number'}, page_content='5/14 <!-- page_number, from page 0 (l=0.931,t=0.972,r=0.959,b=0.980), with ID c220d0d5-e779-4c5e-9bfc-c40591b05cbb -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Header'}, page_content='26/04/2025, 18:05 <!-- page_header, from page 1 (l=0.039,t=0.019,r=0.147,b=0.027), with ID 33b3d629-f6f4-436e-8c5e-4a920a03fb51 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'K 7 Power Flex Home | Kärcher'}, page_content='This is a page header indicating the title of a product, specifically the "K 7 Power Flex Home" by Kärcher. <!-- page_header, from page 1 (l=0.484,t=0.019,r=0.672,b=0.028), with ID 004386be-2519-481f-a8bf-f500439fe918 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Document Details'}, page_content='- **Fördermenge (l/h)**: max. 600\n- **Flächenleistung (m²/h)**: 60\n- **Zulauftemperatur (°C)**: max. 60\n- **Anschlussleistung (kW)**: 3\n- **Anschlusskabel (m)**: 5\n- **Farbe**: gelb\n- **Gewicht ohne Zubehör (kg)**: 17,3\n- **Gewicht inkl. Verpackung (kg)**: 24,9'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Document Details'}, page_content='- **Gewicht inkl. Verpackung (kg)**: 24,9\n- **Abmessungen (L × B × H) (mm)**: 458 × 330 × 666 <!-- key_value, from page 1 (l=0.079,t=0.046,r=0.656,b=0.383), with ID a5cbc49f-259b-43d8-afe4-4122b7d1d94c -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Lieferumfang'}, page_content='- Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger, 3in1, 1 l\n- Hochdruckpistole: G 180 Q\n- Dreckfräser\n- HD-Schlauch: 10 m, PremiumFlex\n- Adapter Gartenschlauchanschluss A3/4" <!-- text, from page 1 (l=0.064,t=0.399,r=0.609,b=0.589), with ID 971dd211-1a6b-4738-92da-1feaf4e6ce9c -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Ausstattung'}, page_content="- Vario Power Jet\n- Integriertes Aufbewahrungsnetz\n- Geräteseitiges Quick Connect\n- Reinigungsmittel-einsatz über: Plug 'n' Clean-System\n- Teleskopgriff\n- Wassergekühlter Motor"),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Ausstattung'}, page_content='- Teleskopgriff\n- Wassergekühlter Motor\n- Integrierter Wasserfilter <!-- text, from page 1 (l=0.062,t=0.626,r=0.489,b=0.886), with ID 3679a92a-e76b-4926-9818-6b7e2ad114fc -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Footer'}, page_content='[https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flex-home-13173020.html](https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flex-home-13173020.html) <!-- page_footer, from page 1 (l=0.039,t=0.972,r=0.626,b=0.982), with ID c3e907b3-522b-401f-8f85-284434afd015 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Footer', 'Header 3': 'Page Number'}, page_content='6/14 <!-- page_number, from page 1 (l=0.931,t=0.972,r=0.959,b=0.980), with ID b1c5e40f-9f17-440f-8804-859f2c79a1dd -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Header'}, page_content='26/04/2025, 18:05 <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.147,b=0.027), with ID 97109ec7-59a1-478a-ab83-8a85be65a0a8 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'K 7 Power Flex Home | Kärcher'}, page_content='This is a page header indicating the product name "K 7 Power Flex Home" by the brand "Kärcher". <!-- page_header, from page 0 (l=0.484,t=0.019,r=0.674,b=0.028), with ID 3967f212-be56-416d-abe2-dbca8f96a932 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='The image is a simple black and white icon. It features a stylized representation of a computer screen with a document on it. The document is depicted with a few horizontal lines, suggesting text, and a folded corner, indicating a page. Below the icon, there is text in German: "ONLINE LESEN," which'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='there is text in German: "ONLINE LESEN," which translates to "READ ONLINE" in English. This suggests that the icon is likely used to indicate an option to read a document or publication online. <!-- figure, from page 0 (l=0.064,t=0.045,r=0.304,b=0.207), with ID 0afe9586-bd25-4f88-a3dc-e3682298fe81'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='with ID 0afe9586-bd25-4f88-a3dc-e3682298fe81 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'ANWENDUNGSGEBIETE'}, page_content='- Terrasse\n- Zäune\n- Garten- und Steinmauern\n- Flächen rund um Haus und Garten\n- Autos\n- Wohnmobile\n- Fahrräder\n- Motorräder und -roller\n- Gartengeräte und -werkzeuge'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'ANWENDUNGSGEBIETE'}, page_content='- Gartengeräte und -werkzeuge\n- Garten-/Terrassen-/Balkonmöbel <!-- text, from page 0 (l=0.064,t=0.530,r=0.356,b=0.925), with ID f0f34efc-9fac-4d64-a200-265dac57e5f9 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Footer'}, page_content='[https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-home-13173020.html](https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-home-13173020.html) <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.626,b=0.981), with ID fd6f71ae-6006-438d-bdc4-ccf60fcc7f63 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Number'}, page_content='9/14 <!-- page_number, from page 0 (l=0.931,t=0.972,r=0.959,b=0.980), with ID 8d25db17-37e7-4007-8211-a098adeddc01 -->  \n---'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Kärcher Logo'}, page_content='The image displays the Kärcher logo. It features the brand name "KÄRCHER" in bold, black uppercase letters. Below the text, there is a solid yellow horizontal line. The logo is simple and uses a clean, modern font, emphasizing the brand\'s identity. <!-- page_header, from page 0'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Kärcher Logo'}, page_content="brand's identity. <!-- page_header, from page 0 (l=0.062,t=0.031,r=0.223,b=0.063), with ID 828975e1-8dd2-4054-b07a-6d651450581b -->"),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'K 7 POWER FLEX'}, page_content='Für mehr Power: der K 7 Power Flex-Hochdruckreiniger mit PremiumFlex-Schlauch, G 180 Q-Pistole, für hartnäckige Verschmutzungen auf Terrassen, Wegen und Autos geeignet. <!-- text, from page 0 (l=0.064,t=0.080,r=0.927,b=0.148), with ID e357413c-a32e-4414-92a7-c8deadcb775a -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='The image shows a pressure washer, specifically the Kärcher K7 model. It is predominantly yellow with black accents. The device is designed for high-pressure cleaning tasks and features a sturdy handle for easy maneuverability. It has large wheels for transport and a hose reel for convenient storage'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='transport and a hose reel for convenient storage of the hose.'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description', 'Header 3': 'Key Features:'}, page_content='- **Model**: K7\n- **Brand**: Kärcher\n- **Color**: Yellow and black\n- **Components**:\n- Main unit with a handle and wheels\n- Two detachable nozzles/lances for different cleaning tasks'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description', 'Header 3': 'Design Details:'}, page_content='- **Main Unit**:\n- The body is primarily yellow with black sections.\n- The Kärcher logo is visible on the front.\n- The handle is ergonomically designed for easy grip.\n- The unit has a hose reel for organizing the hose neatly.  \n- **Nozzles**:\n- Two black nozzles are shown in front of the main unit.'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description', 'Header 3': 'Design Details:'}, page_content='- They are designed to attach to the main unit for various cleaning applications.'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description', 'Header 3': 'Design Details:'}, page_content='This pressure washer is suitable for heavy-duty cleaning tasks, such as washing vehicles, driveways, and outdoor surfaces. <!-- figure, from page 0 (l=0.066,t=0.192,r=0.934,b=0.866), with ID 7ef9330e-2aae-47c2-8a0c-98bcffdeb286 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Price Information'}, page_content='- **Price**: 504,99 €\n- **Includes**: inkl. MwSt.\n- **Delivery**: kostenlose Lieferung ab 50 € <!-- text, from page 0 (l=0.087,t=0.882,r=0.404,b=0.932), with ID 5c69ee43-47ab-4dc3-8122-e4d219dcc599 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Footer'}, page_content='[https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-13173000.html](https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-13173000.html) <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.587,b=0.981), with ID b09fbb3d-9523-47b4-b92d-ff9a5792ab8c -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Header'}, page_content='- **Date and Time**: 26/04/2025, 18:02\n- **Product**: K 7 Power Flex | Kärcher <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.654,b=0.028), with ID bda16bd9-0758-4dff-aba9-b7248354d198 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Header', 'Header 3': 'Page Number'}, page_content='1/15 <!-- page_number, from page 0 (l=0.932,t=0.972,r=0.959,b=0.980), with ID f72ccc29-5b55-4e16-9e70-5d544bb42a11 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Header'}, page_content='26/04/2025, 18:02 <!-- page_header, from page 1 (l=0.039,t=0.019,r=0.149,b=0.027), with ID 29d70f8e-ace8-40d4-bb96-35ffd9be6038 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'K 7 Power Flex | Kärcher'}, page_content='This is a page header indicating the title "K 7 Power Flex" associated with the brand "Kärcher". <!-- page_header, from page 1 (l=0.504,t=0.019,r=0.654,b=0.028), with ID f2902769-9770-4a00-a17f-149a9541af7e -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Key-Value Information'}, page_content='- **Lieferbar in**: 2-3 Werktagen\n- **Bestellnummer**: 1.317-300.0 <!-- key_value, from page 1 (l=0.087,t=0.037,r=0.300,b=0.069), with ID 0f534138-95e2-4173-8626-490631fa9bf2 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Händlersuche <!-- text, from page 1 (l=0.087,t=0.112,r=0.191,b=0.122), with ID 2815a31f-8b2d-4b34-921c-246bf30cc160 -->', 'Header 3': 'Form Field'}, page_content='- **Label**: Ort oder PLZ\n- **Input Field**: Empty (no text entered) <!-- form, from page 1 (l=0.086,t=0.125,r=0.390,b=0.163), with ID 5dfffa2c-9cc0-4d12-81d8-2a599cc6bd63 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Figure Description'}, page_content='The image displays a rating system with the following details:  \n- **Stars**: There are 4.5 out of 5 stars filled in yellow, indicating a high rating.\n- **Numerical Rating**: The text "4.7" is shown next to the stars, representing the average rating.'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Figure Description'}, page_content='- **Number of Reviews**: The number "(56)" is displayed, indicating that 56 reviews have contributed to this rating.'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Figure Description'}, page_content='- **Call to Action**: The text "Jetzt Produkt bewerten" is present, which translates to "Rate the product now" in English. This suggests an invitation for users to submit their own ratings. <!-- figure, from page 1 (l=0.099,t=0.196,r=0.499,b=0.218), with ID 4283abc4-b315-40af-9dc1-3934c117ff2c -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Produkt vergleichen'}, page_content='- The text is in German and translates to "Compare product" in English.\n- The text appears to be a clickable element, possibly a button or link, indicated by the arrow symbol (`>`). <!-- text, from page 1 (l=0.084,t=0.255,r=0.255,b=0.268), with ID 5edb5fc0-3764-4e45-aded-bd6ff45751ba -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Benötigen Sie Hilfe?'}, page_content='Hotline: +49 7195 903 0 <!-- text, from page 1 (l=0.087,t=0.308,r=0.270,b=0.332), with ID a8945087-836f-4d76-b837-c42a0b99a36d -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text'}, page_content='Mit dem Hochdruckreiniger K 7 Power Flex lässt sich jede Oberfläche mit passendem Druck reinigen. Um den richtigen Druck zu finden, unterstützt der in der Kärcher Home & Garden App integrierte Anwendungsberater den Nutzer mit praktischen Tipps zu jeder Reinigungssituation und jedem Reinigungsobjekt'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text'}, page_content='Reinigungssituation und jedem Reinigungsobjekt – für perfekte Reinigungsergebnisse. Der K 7 Power Flex ist mit einem wassergekühlten Motor ausgestattet und wurde gebaut für häufige Reinigungseinsätze und starke Verschmutzungen, wie man sie zum Beispiel von Wegen, Schwimmbecken, Fahrrädern oder'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text'}, page_content='von Wegen, Schwimmbecken, Fahrrädern oder großen Autos kennt. Das reichhaltige Ausstattungspaket reicht von einer Pistole mit praktischem Quick Connect-Anschluss über einen PremiumFlex-Hochdruckschlauch und einen zuverlässigen Wasserfilter zum Schutz der Pumpe bis zu einem Vario Power-Strahlrohr'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text'}, page_content='der Pumpe bis zu einem Vario Power-Strahlrohr (VPS) sowie einem Dreckfräser mit rotierendem Punktstrahl. Die Druckeinstellung am VPS lässt sich buchstäblich im Handumdrehen variieren, und der Dreckfräser macht selbst hartnäckigsten Verschmutzungen den Garaus. Weitere Ausstattungsdetails sind das'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Text'}, page_content="den Garaus. Weitere Ausstattungsdetails sind das Plug 'n' Clean-Reinigungsmittelsystem, der Aluminium-Teleskopgriff und die Parkposition für griffbereites Zubehör. <!-- text, from page 1 (l=0.064,t=0.445,r=0.926,b=0.609), with ID bfc84457-86eb-4293-8f24-a47185726d50 -->"),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'MERKMALE UND VORTEILE'}, page_content='The text in the image reads "MERKMALE UND VORTEILE," which translates to "FEATURES AND BENEFITS" in English. <!-- text, from page 1 (l=0.064,t=0.636,r=0.281,b=0.646), with ID 6f424b12-1184-4207-8b86-b98f156317f6 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Footer'}, page_content='https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-13173000.html <!-- page_footer, from page 1 (l=0.039,t=0.972,r=0.587,b=0.981), with ID 9349a566-c6b8-4971-95cf-2d6ab4dbc8a1 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Footer', 'Header 3': 'Page Header'}, page_content='- **Date and Time**: 26/04/2025, 18:02\n- **Title**: K 7 Power Flex | Kärcher <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.654,b=0.027), with ID be6d4c6a-5f65-49b1-b38e-13f8e3d7c342 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='The image shows a hand placing a container into a slot on a Kärcher cleaning device. The container is labeled with the text "BRING BACK THE WOW" and "CLEAN MAINTAIN." The Kärcher logo is visible on the container. The device has a black and yellow color scheme, typical of Kärcher products. The hand'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='scheme, typical of Kärcher products. The hand is wearing a gray sleeve.'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='Below the image, there is a caption in German: "Plug \'n\' Clean – das Kärcher Reinigungsmittelsystem," which translates to "Plug \'n\' Clean – the Kärcher cleaning agent system." This suggests that the system allows for easy insertion and use of cleaning agents with the device. <!-- figure, from page'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Description'}, page_content='agents with the device. <!-- figure, from page 0 (l=0.062,t=0.031,r=0.935,b=0.663), with ID a293dc70-be80-41f6-bb46-053a3154329b -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Schnell, einfach, komfortabel'}, page_content="Dank Plug 'n' Clean lässt sich das Reinigungsmittel mit nur einem Handgriff bequem austauschen. <!-- text, from page 0 (l=0.064,t=0.669,r=0.914,b=0.694), with ID def48216-2327-4027-b384-6dbfc9f26d6f -->"),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Überragende Leistung'}, page_content='- Der wassergekühlte Motor besticht durch seine besondere Langlebigkeit und Leistungsfähigkeit. <!-- text, from page 0 (l=0.081,t=0.726,r=0.818,b=0.767), with ID f3622845-4e56-47ab-b01d-17e7a02774d9 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Technische Daten'}, page_content='- **Stromart (V/Hz)**: 230 / 50\n- **Druck (bar/MPa)**: 20 - max. 180 / 2 - max. 18 <!-- text, from page 0 (l=0.064,t=0.853,r=0.740,b=0.939), with ID d9df9c20-310a-4cfb-bb1c-9d0d940ebfa7 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Footer'}, page_content='[https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-13173000.html](https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flax-13173000.html) <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.587,b=0.981), with ID d99a11e0-9337-4927-b58c-3260e7b50a10 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Number'}, page_content='5/15 <!-- page_number, from page 0 (l=0.931,t=0.972,r=0.959,b=0.980), with ID 848ceb2d-4127-4c8d-99c0-2e622e0895f7 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Header'}, page_content='26/04/2025, 18:02 <!-- page_header, from page 1 (l=0.039,t=0.019,r=0.149,b=0.027), with ID 06ad21bf-ab3a-4e66-95ca-4abef91ab0fd -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Header', 'Header 3': 'K 7 Power Flex | Kärcher'}, page_content='This is a page header indicating the title or section name "K 7 Power Flex" associated with the brand "Kärcher". <!-- page_header, from page 1 (l=0.504,t=0.019,r=0.654,b=0.028), with ID a040ecfb-3edc-4b7a-9b92-5dbf8aa8fa3d -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Document Details'}, page_content='- **Fördermenge (l/h)**: max. 600\n- **Flächenleistung (m²/h)**: 60\n- **Zulauftemperatur (°C)**: max. 60\n- **Anschlussleistung (kW)**: 3\n- **Anschlusskabel (m)**: 5\n- **Farbe**: gelb\n- **Gewicht ohne Zubehör (kg)**: 17,3\n- **Gewicht inkl. Verpackung (kg)**: 23'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Document Details'}, page_content='- **Gewicht inkl. Verpackung (kg)**: 23\n- **Abmessungen (L × B × H) (mm)**: 458 x 330 x 660 <!-- key_value, from page 1 (l=0.077,t=0.044,r=0.649,b=0.384), with ID 5fbda869-b8f6-4aaa-92bb-a5c48aa62b46 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Lieferumfang'}, page_content='The text in the crop is "Lieferumfang". <!-- text, from page 1 (l=0.064,t=0.399,r=0.189,b=0.413), with ID 24670c17-f8fc-4148-9c35-bfc823a08c84 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Document Details'}, page_content='- **Hochdruckpistole**: G 180 Q\n- **Dreckfräser**\n- **HD-Schlauch**: 10 m, PremiumFlex\n- **Adapter Gartenschlauchanschluss**: A3/4" <!-- text, from page 1 (l=0.084,t=0.432,r=0.402,b=0.553), with ID 578732bf-ed52-4653-a235-1bebcf6f0df8 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Features'}, page_content="- Vario Power Jet\n- Integriertes Aufbewahrungsnetz\n- Geräteseitiges Quick Connect\n- Reinigungsmittel-einsatz über: Plug 'n' Clean-System\n- Teleskopgriff\n- Wassergkühlter Motor"),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Features'}, page_content='- Teleskopgriff\n- Wassergkühlter Motor\n- Integrierter Wasserfilter <!-- text, from page 1 (l=0.084,t=0.622,r=0.489,b=0.850), with ID 36c9dea8-1b9d-441a-9f79-e6267ec549e2 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Features', 'Header 3': 'Page Footer Information'}, page_content='- **URL**: [https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flex-13173000.html](https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-power-flex-13173000.html)'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Features', 'Header 3': 'Page Footer Information'}, page_content='This URL appears to be a link to a product page on the Kärcher website, specifically for a high-pressure cleaner model "K 7 Power Flex." <!-- page_footer, from page 1 (l=0.039,t=0.972,r=0.587,b=0.982), with ID d8b6dce1-b251-4963-ac24-f55991774bf8 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Features', 'Header 3': 'Page Number'}, page_content='6/15 <!-- page_number, from page 1 (l=0.931,t=0.972,r=0.959,b=0.980), with ID 6aea910b-76f3-44ce-bd6a-b125110ad7a7 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'Page Header'}, page_content='- Date and Time: 26/04/2025, 18:02\n- Product: K 7 Power Flex | Kärcher <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.654,b=0.028), with ID 2a52458c-b355-4814-9515-e9ae484eb99c -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'ANWENDUNGSGEBIETE'}, page_content='- Terrasse\n- Zäune\n- Garten- und Steinmauern\n- Flächen rund um Haus und Garten\n- Autos\n- Wohnmobile\n- Fahrräder\n- Motorräder und -roller\n- Gartengeräte und -werkzeuge'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'ANWENDUNGSGEBIETE'}, page_content='- Gartengeräte und -werkzeuge\n- Garten-/Terrassen-/Balkonmöbel <!-- text, from page 0 (l=0.064,t=0.230,r=0.356,b=0.624), with ID 0e68cf0f-3e88-4f51-9671-7e2d361766fd -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'K 7 POWER FLEX ERSATZTEILE'}, page_content='This text appears to be a heading or title related to replacement parts for a product named "K 7 Power Flex." <!-- text, from page 0 (l=0.064,t=0.714,r=0.311,b=0.724), with ID 8759019e-531f-4127-a4da-d0835885d409 -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'KÄRCHER ORIGINAL-ERSATZTEILE'}, page_content='Egal, wo Sie Ihr Kärcher-Gerät gekauft haben, Sie können sich im Reparaturfall an jeden **Kärcher-Fachhändler** in Ihrer Nähe wenden. Ersatzteile dürfen lediglich von ausgebildetem Fachpersonal getauscht werden. Bitte beachten Sie die [Garantiebedingungen](#). <!-- text, from page 0'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'KÄRCHER ORIGINAL-ERSATZTEILE'}, page_content='[Garantiebedingungen](#). <!-- text, from page 0 (l=0.064,t=0.762,r=0.915,b=0.826), with ID cb0f9b3f-5d60-4f3e-be15-cf842047ddce -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'HOME & GARDEN GERÄTE'}, page_content='- Ihr Kärcher-Gerät können Sie über den Online-Reparaturservice im myKärcher Kundenportal einschicken. Alternativ können Sie Ihr Ersatzteil einfach und bequem in unserem Onlineshop bestellen. <!-- text, from page 0 (l=0.064,t=0.840,r=0.894,b=0.889), with ID 2d8f8f48-a9df-43bb-a601-049eabc4a34e -->'),
#  Document(metadata={'Header 1': 'K 7 POWER FLEX HOME <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with ID 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->', 'Header 2': 'PROFESSIONAL GERÄTE'}, page_content='- Kleingeräte können Sie über das [myKärcher Kundenportal](#) einschicken. Alternativ können Sie Ihr Ersatzteil einfach und bequem in unserem Onlineshop [bestellen](#). <!-- text, from page 0 (l=0.064,t=0.901,r=0.904,b=0.951), with ID f1da39f1-dbed-4f5c-ac14-5444309709b8 -->'),
# ...
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Technische Daten'}, page_content='- **Stromart (V/Hz)**: 230 / 50\n- **Druck (bar/MPa)**: 20 - max. 180 / 2 - max. 18\n- **Fördermenge (l/h)**: max. 600\n- **Flächenleistung (m²/h)**: 60\n- **Zulauftemperatur (°C)**: max. 60\n- **Anschlussleistung (kW)**: 3\n- **Anschlusskabel (m)**: 5\n- **Farbe**: gelb'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Technische Daten'}, page_content='- **Anschlusskabel (m)**: 5\n- **Farbe**: gelb\n- **Gewicht ohne Zubehör (kg)**: 17,7\n- **Gewicht inkl. Verpackung (kg)**: 22,4\n- **Abmessungen (L × B × h) (mm)**: 369 x 394 x 946 <!-- key_value, from page 0 (l=0.064,t=0.333,r=0.741,b=0.785), with ID c66ae747-b25b-4f74-97fc-57f6aafb3918 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Lieferumfang'}, page_content='- Hochdruckpistole: G 180 Q\n- Dreckfräser\n- HD-Schlauch: 10 m <!-- text, from page 0 (l=0.064,t=0.817,r=0.302,b=0.933), with ID b5e04d7d-fe0b-4e8c-82f8-92b265b6b2d9 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Page Footer'}, page_content='https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-wcm-premium-13174200.html <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.610,b=0.981), with ID ac74c7e9-5112-42d1-a029-9ec297901094 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Page Header'}, page_content='26/04/2025, 18:07 <!-- page_header, from page 1 (l=0.039,t=0.019,r=0.147,b=0.027), with ID 243fedc7-f081-4c43-9096-df3bb51bc0ff -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'K 7 WCM Premium | Kärcher'}, page_content='This is a page header indicating the title or section of a document related to the Kärcher K 7 WCM Premium product. <!-- page_header, from page 1 (l=0.491,t=0.019,r=0.665,b=0.028), with ID 67000a48-8462-4d88-9997-8999002fc65c -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'K 7 WCM Premium | Kärcher'}, page_content='- Adapter Gartenschlauchanschluss A3/4" <!-- text, from page 1 (l=0.084,t=0.044,r=0.402,b=0.057), with ID bf6ba201-88ae-485a-8f71-05e397e125b4 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'K 7 WCM Premium | Kärcher', 'Header 3': 'Ausstattung'}, page_content='- Vario Power Jet\n- Integrierte HD-Schlauchtrommel\n- Reinigungsmitteleinsatz über: Ansaugschlauch\n- Wassergekühlter Motor\n- Integrierter Wasserfilter <!-- text, from page 1 (l=0.064,t=0.093,r=0.450,b=0.281), with ID df8e2ba4-c387-433b-90a3-f2332241c3c5 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='The image is a logo with a blue, angular shape resembling a speech bubble or a stylized map. Inside this shape, there are twelve yellow stars arranged in a circle, representing the European Union flag. Below the blue shape, the text "Made in Europe" is written in black, bold letters. This logo'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='is written in black, bold letters. This logo signifies that the product or item is manufactured in Europe. <!-- figure, from page 1 (l=0.064,t=0.308,r=0.395,b=0.503), with ID 1a9ee675-8c84-47f3-8ce1-49eaca473a2e -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='The image is a graphical representation with a black background and yellow elements. It features a stylized design that includes arrows and circular shapes, possibly indicating movement or flow. The design is abstract and does not resemble any specific object.'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='Below the design, there is text in bold yellow that reads:  \n**+100% POWER**  \nThis suggests an emphasis on increased power or efficiency, possibly related to a product or feature.  \nUnderneath the main graphic, there is a gray section with the word:  \n**LANGLEBIG**'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='**LANGLEBIG**  \nThis word is in white, bold, uppercase letters, and may indicate durability or longevity, as "langlebig" is German for "long-lasting."'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='The overall design and text suggest a focus on enhanced performance and durability. <!-- figure, from page 1 (l=0.425,t=0.308,r=0.758,b=0.586), with ID 5edfe9bc-f137-408e-b378-4c88dcc5479b -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='The image is a graphical representation labeled "VARIO POWER." It features a stylized depiction of a pressure washer nozzle. The nozzle is shown with a directional arrow pointing downward, indicating the flow of water. Above the nozzle, there are symbols for plus (+) and minus (-), suggesting'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='symbols for plus (+) and minus (-), suggesting adjustable power settings. The plus sign is larger and more prominent, indicating an increase in power, while the minus sign is smaller, indicating a decrease. The background is black, and the graphics and text are in yellow, providing high contrast'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='and text are in yellow, providing high contrast for visibility. The overall design suggests a focus on variable power control for a pressure washer. <!-- figure, from page 1 (l=0.061,t=0.540,r=0.395,b=0.775), with ID 54905457-28d9-4276-a068-8912ca489a0d -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='The image is a graphical representation with a black background. It features a yellow icon resembling an hourglass or a stylized engine component. Below the icon, there is text in white that reads:  \n**WASSERGEKÜHLTER MOTOR**'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='This translates from German to "water-cooled engine" in English. The icon and text together suggest that the figure is indicating a feature or specification related to a water-cooled motor. The use of yellow and black may imply caution or highlight the importance of this feature. <!-- figure, from'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Figure Description'}, page_content='the importance of this feature. <!-- figure, from page 1 (l=0.426,t=0.615,r=0.771,b=0.776), with ID 83f43c82-3bcf-40d7-8907-5773621886e1 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Produktinformation'}, page_content='The text in the image is "Produktinformation". <!-- text, from page 1 (l=0.064,t=0.848,r=0.214,b=0.859), with ID ff3aff9e-14ff-4ec8-bc06-595aa0b6616c -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Bedienungsanleitung'}, page_content='The text in the image is "Bedienungsanleitung," which translates to "User Manual" or "Instruction Manual" in English. <!-- text, from page 1 (l=0.446,t=0.849,r=0.604,b=0.861), with ID d463a921-b05c-4506-80eb-43c53f22d917 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Page Footer'}, page_content='https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-wcm-premium-13174200.html <!-- page_footer, from page 1 (l=0.039,t=0.972,r=0.610,b=0.982), with ID 8a5689b4-6f34-4d23-9b59-352bb1ee17fa -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Page Footer', 'Header 3': 'Page Number'}, page_content='4/9 <!-- page_number, from page 1 (l=0.939,t=0.972,r=0.959,b=0.980), with ID ab88c1b5-c5a4-4d32-aadc-b814c6070f06 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Page Header'}, page_content='- **Date and Time**: 26/04/2025, 18:07  \nThis crop from a document header displays a date and time, formatted as day/month/year and hour:minute. <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.149,b=0.027), with ID 4d23b27a-04fb-4649-abd8-786602187e53 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Page Header', 'Header 3': 'K7 WCM Premium | Kärcher'}, page_content='This is a page header indicating the title or section of a document related to the "K7 WCM Premium" product by Kärcher. <!-- page_header, from page 0 (l=0.491,t=0.019,r=0.665,b=0.028), with ID fb5dd6cc-64ec-4166-b9ef-c30e78092c5a -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'ANWENDUNGSGEBIETE'}, page_content='- Garten-/Terrassen-/Balkonmöbel\n- Gartengeräte und -werkzeuge\n- Autos\n- Wohnmobile\n- Motorräder und -roller\n- Fahrräder <!-- text, from page 0 (l=0.064,t=0.230,r=0.350,b=0.478), with ID a007466b-ff92-4c03-b311-0d41c686dee4 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'K 7 WCM PREMIUM ERSATZTEILE', 'Header 3': 'KÄRCHER ORIGINAL-ERSATZTEILE'}, page_content='Egal, wo Sie Ihr Kärcher-Gerät gekauft haben, Sie können sich im Reparaturfall an jeden **Kärcher-Fachhändler** in Ihrer Nähe wenden. Ersatzteile dürfen lediglich von ausgebildetem Fachpersonal getauscht werden. Bitte beachten Sie die [Garantiebedingungen](#). <!-- text, from page 0'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'K 7 WCM PREMIUM ERSATZTEILE', 'Header 3': 'KÄRCHER ORIGINAL-ERSATZTEILE'}, page_content='[Garantiebedingungen](#). <!-- text, from page 0 (l=0.064,t=0.569,r=0.916,b=0.682), with ID dce3f748-89ee-4de5-b06f-da0fb0ab66dc -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'HOME & GARDEN GERÄTE'}, page_content='- Ihr Kärcher-Gerät können Sie über den Online-Reparaturservice im myKärcher Kundenportal einschicken. Alternativ können Sie Ihr Ersatzteil einfach und bequem in unserem Onlineshop bestellen. <!-- text, from page 0 (l=0.064,t=0.695,r=0.894,b=0.745), with ID d761cc50-44a7-449d-b105-5c359f2429d1 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'PROFESSIONAL GERÄTE'}, page_content='- Kleingeräte können Sie über das myKärcher Kundenportal einschicken. Alternativ können Sie Ihr Ersatzteil einfach und bequem in unserem Onlineshop bestellen.\n- Großgeräte oder Installationen können Sie vor Ort von unserem Werkskundendienst reparieren lassen.'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'PROFESSIONAL GERÄTE'}, page_content='- Informationen zu unseren Ersatzteilen können Sie in unserer Ersatzteilliste nachlesen. <!-- text, from page 0 (l=0.064,t=0.757,r=0.904,b=0.837), with ID aa1bcf09-53a3-4708-b459-65cb95fcf88d -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Page Footer'}, page_content='https://www.kaercher.com/de/home-garden/hochdruckreiniger/k-7-wcm-premium-13174200.html <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.610,b=0.981), with ID c119e435-30c3-4d3a-8b45-1c9249fbee55 -->'),
#  Document(metadata={'Header 1': 'K 7 SMART CONTROL FLEX eco!Booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with ID 430bb76c-671d-48bf-8513-c1f8d83bec18 -->', 'Header 2': 'Page Footer'}, page_content='69 <!-- page_footer, from page 0 (l=0.939,t=0.972,r=0.959,b=0.980), with ID 02f5e3d4-3aa9-4b61-8489-d791700eb578 -->  \n---'),
#  ...]

# %%
from copy import deepcopy


def update_documents_with_headers(chunks):
    """
    Creates a new list of Document objects with page_content prepended with headers
    in [Header1/Header2/Header3]: format
    
    Returns new objects rather than modifying the original chunks
    """
    updated_chunks = []
    max_depth=3 
    
    for doc in chunks:
        # Create a deep copy of the document to avoid modifying the original
        new_doc = deepcopy(doc)
        
        # Get all headers that exist in metadata
        headers = []
        for i in range(1, max_depth + 1):
            key = f'Header {i}'
            if key in new_doc.metadata:
                headers.append(f"{key}: {new_doc.metadata[key]}")
        
        # Create the header prefix and update page_content
        if headers:
            prefix = f"[{'/'.join(headers)}]: "
            new_doc.page_content = prefix + "\n" + new_doc.page_content
        
        updated_chunks.append(new_doc)
    
    return updated_chunks


docs = update_documents_with_headers(filtered_chunks)

# %%
import re

product_names = [
 'K 7 Premium Smart Control Flex eco!B',
 'K 7 Premium Smart Control Flex Home',
 'K 7 Premium Power Flex',
 'K 7 Premium Power Flex Home',
 'K 7 Premium Smart Control Flex',
 'K 7 Smart Control Flex eco!Booster',
 'K 7 Smart Control Flex Home',
 'K 7 Power Flex',
 'K 7 Power Flex Home',
 'K 7 Smart Control Flex',
 'K 7 WCM Premium Home',
 'K 7 WCM',
 'K 7 WCM Car&Home',
 'K 7 WCM FJ',
 'K 7 WCM Premium',
 'K 5 Premium Smart Control Flex eco!Booster',
 'K 5 Power Control Flex',
 'K 5 Power Control Flex Home',
 'K 5 WCM',
 'K 5 WCM Premium',
 'K 5 WCM Premium Home',
 'K 5 Classic',
 'K 5 Classic Car & Home',
 'K 5 Classic Home',
 'K 5 FJ',
 'K 5 FJ Home',
 'K 5 Premium Smart Control Flex Home',
 'K 5 Power Control Flex Home&Brush Anniversary Edition',
 'K 5 Premium Power Control Flex',
 'K 5 Premium Power Control Flex Home',
 'K 5 Premium Smart Control Flex',
 'K 5 Smart Control Flex eco!Booster',
 'K 4 Premium Power Control Flex',
 'K 4 FJ',
 'K 4 FJ Home',
 'K 4 WCM Premium',
 'K 4 Classic',
 'K 4 Classic Car',
 'K 4 Classic Home',
 'K 4 WCM Premium Home',
 'K Silent Anniversary Edition',
 'K Silent eco!Booster',
 'K 4 Power Control Flex',
 'K 4 Power Control Flex Home',
 'K 4 Premium Power Control Flex Home',
 'K 4 WCM',
 'K 3 Power Control',
 'K 3 Classic',
 'K 3 Classic Car',
 'K 3 FJ',
 'K 3 FJ Home',
 'K 3 Horizontal Plus Home',
 'K 3 Power Control Home T 5',
 'K 3 Premium Power Control',
 'K 3 Horizontal Plus',
 'K 2 Premium FJ',
 'K 2 Battery',
 'K 2 Classic',
 'K 2 Power Control',
 'K 2 Power Control Car & Home',
 'K 2 Premium FJ Home',
 'K 2 Premium Horizontal VPS Home',
 'K 2 Battery Set',
 'K 2 Horizontal VPS',
 'K 2 Power Control Home',
 'K 2 Universal Edition',
 'K 2 Universal Edition Home',
 'K Mini'
]


def clean_content(text):


    text = re.sub(r"http\S+", "", text)  # Remove URLs
    text = re.sub(r"\s+", " ", text).strip()
    # Step 1: Temporarily replace product names with placeholders
    placeholders = {}
    for i, name in enumerate(product_names):
        placeholder = f"__PRODUCT_{i}__"
        placeholders[placeholder] = name
        text = text.replace(name, placeholder)

    # Step 2: Clean the rest of the text (lowercase, remove links, etc.)
    text = text.lower()
    

    # Step 3: Restore product names with original casing
    for placeholder, name in placeholders.items():
        text = text.replace(placeholder, name)

    return text

# %%
# Apply clean_content to each document's page_content
for doc in docs:
    doc.page_content = clean_content(doc.page_content)

# %%
for doc in docs:
    print(doc.page_content, end="\n\n")
# Out:
# [header 2: page header]: the image displays the logo of kärcher, a company known for its cleaning equipment. the logo consists of the word "kärcher" in bold, black uppercase letters. below the text, there is a yellow horizontal bar. the background is white, providing contrast to the black text and yellow bar. <!--
#
# [header 2: page header]: contrast to the black text and yellow bar. <!-- page_header, from page 0 (l=0.062,t=0.031,r=0.223,b=0.063), with id b870019e-e912-44a9-b958-687bea146dcc -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text]: für mehr power: __product_7__ home hochdruckreiniger mit premiumflex-schlauch, g 180 q-pistole für hartnäckige verschmutzungen rund ums haus. inkl. home kit. <!-- text, from page 0 (l=0.064,t=0.121,r=0.850,b=0.148), with id 9ee6b603-ece9-4526-85da-a653334c1b50 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: the image displays a kärcher k7 pressure washer set, which includes several components:
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: - **main unit**: the central piece is the kärcher k7 pressure washer, characterized by its yellow and black color scheme. it has a sturdy handle for easy maneuverability and large wheels for transport. the model name "k7" is prominently displayed on the side. - **accessories**:
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: - **accessories**: - **surface cleaner**: a circular attachment designed for cleaning flat surfaces. it is also yellow and black, matching the main unit.
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: - **spray lances**: two different spray lances are included, each designed for specific cleaning tasks. they are black and attach to the main unit. - **detergent bottle**: a bottle labeled "stone & facade" is included, indicating it is a cleaning solution specifically for stone surfaces.
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: this set is designed for high-performance cleaning, suitable for various outdoor surfaces. <!-- figure, from page 0 (l=0.065,t=0.192,r=0.934,b=0.866), with id fc9582c1-5cdc-43a2-8037-20ccf547f2f3 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: price]: 574,99 € <!-- text, from page 0 (l=0.089,t=0.882,r=0.251,b=0.907), with id 75d48396-2c0c-44cb-9f01-3c0dc89b119b -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text content]: inkl. mwst. - kostenlose lieferung ab 50 € <!-- text, from page 0 (l=0.087,t=0.920,r=0.404,b=0.932), with id d3e3ba9e-b11c-40d5-a572-128adb790ab3 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header]: 26/04/2025, 18:05 <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.149,b=0.027), with id a9c01ec5-8216-4d33-b700-304b87615ff0 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page number]: 1/14 <!-- page_number, from page 0 (l=0.932,t=0.972,r=0.959,b=0.980), with id f4d8d62b-3ec7-4a80-99b2-c277a43d2b65 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer]: [ <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.626,b=0.981), with id 16b7a75f-5c86-4379-9589-0da38032f67b -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: __product_7__ home | kärcher]: this is a page header indicating the product name "__product_7__ home" by the brand "kärcher". <!-- page_header, from page 0 (l=0.484,t=0.019,r=0.674,b=0.028), with id 1201169f-a536-4cbd-bf00-67d475a04056 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header]: date: 26/04/2025, 18:05 <!-- page_header, from page 1 (l=0.039,t=0.019,r=0.147,b=0.027), with id 1188b5b6-2032-46f8-aed1-78b5abfe5687 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: __product_7__ home | kärcher]: this is a page header indicating the product name "__product_7__ home" by the brand "kärcher". <!-- page_header, from page 1 (l=0.484,t=0.019,r=0.672,b=0.028), with id 5d635fb4-2165-4d6b-8c67-5520e3678ea6 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text information]: - lieferbar in: 2-3 werktagen - bestellnummer: 1.317-302.0 <!-- key_value, from page 1 (l=0.087,t=0.037,r=0.300,b=0.069), with id ffd326cb-94fb-4daf-9572-1ddaeda87ac1 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: händler suche]: - **ort oder plz**: [input field]
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: händler suche/header 3: bewertung]: - **rating**: ★★★★★ 4.7 (48) - **option**: jetzt produkt bewerten
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: händler suche/header 3: funktionen]: - **produkt vergleichen**: [dropdown or expandable section]
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: händler suche/header 3: hilfe]: - **benötigen sie hilfe?** - **hotline**: +49 7195 903 0 <!-- form, from page 1 (l=0.087,t=0.113,r=0.500,b=0.334), with id 746c2ba4-26f6-43f8-8dea-a45eb9d7ace0 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text]: mit dem hochdruckreiniger __product_7__ home lässt sich jede oberfläche mit passendem druck reinigen. um den richtigen druck zu finden, unterstützt der in der kärcher home & garden app integrierte anwendungsberater den nutzer mit praktischen tipps zu jeder reinigungssituation und jedem
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text]: tipps zu jeder reinigungssituation und jedem reinigungsobjekt – für perfekte reinigungsergebnisse. der __product_7__ home ist mit einem wassergekühlten motor ausgestattet und wurde gebaut für häufige reinigungseinsätze und starke verschmutzungen. das reichhaltige ausstattungspaket reicht von einer
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text]: reichhaltige ausstattungspaket reicht von einer pistole mit praktischem quick connect-anschluss über einen premiumflex-hochdruckschlauch und einen zuverlässigen wasserfilter zum schutz der pumpe bis zu einem vario power-strahlrohr (vps) sowie einem dreckfräser mit rotierendem punktstrahl. die
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text]: dreckfräser mit rotierendem punktstrahl. die druckeinstellung am vps lässt sich buchstäblich im handumdrehen variieren, und der dreckfräser macht selbst hartnäckigsten verschmutzungen den garaus. weitere ausstattungsdetails sind das plug 'n' clean-reinigungssystem, der aluminium-teleskopgriff und
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text]: der aluminium-teleskopgriff und die parkposition für griffbereites zubehör. inklusive home kit mit flächenreiniger t 7 und 1 liter stein- und fassadenreiniger. <!-- text, from page 1 (l=0.064,t=0.445,r=0.921,b=0.623), with id 3d2de5d5-6846-4402-84fd-a69366979781 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer]: [ <!-- page_footer, from page 1 (l=0.039,t=0.972,r=0.626,b=0.981), with id 02328868-e260-4921-8215-f1876ab2b6ff -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header]: 26/04/2025, 18:05 <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.147,b=0.027), with id a717f9f8-a503-4b5c-a8a9-392061d60639 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: __product_7__ home | kärcher]: this is a page header indicating the product name "__product_7__ home" by the brand "kärcher". <!-- page_header, from page 0 (l=0.484,t=0.019,r=0.674,b=0.027), with id 31f6d5dd-c8f4-4114-b96d-86392a41d12f -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: figure description]: the image shows a hand placing a container into a slot on a kärcher cleaning device. the container is labeled with the text "bring back the wow" and "clean maintain." the kärcher logo is visible on the container. the device has a black and yellow color scheme, typical of kärcher products. the hand
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: figure description]: scheme, typical of kärcher products. the hand is positioned to insert the container into the designated area on the device, which appears to be part of a cleaning system.
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: figure description]: below the image, there is a caption in german: "plug 'n' clean – das kärcher reinigungsmittelsystem," which translates to "plug 'n' clean – the kärcher cleaning agent system." this suggests that the system allows for easy insertion and use of cleaning agents with the device. <!-- figure, from page
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: figure description]: agents with the device. <!-- figure, from page 0 (l=0.062,t=0.031,r=0.935,b=0.663), with id fa5a0cb8-4b7b-44d9-bd2e-edc6238b62ee -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: schnell, einfach, komfortabel]: dank plug 'n' clean lässt sich das reinigungsmittel mit nur einem handgriff bequem austauschen. <!-- text, from page 0 (l=0.064,t=0.669,r=0.914,b=0.694), with id 91590b46-4a2a-46b4-ad17-7138cc7e363b -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: überragende leistung]: - der wassergekühlte motor besticht durch seine besondere langlebigkeit und leistungsfähigkeit. <!-- text, from page 0 (l=0.081,t=0.726,r=0.818,b=0.767), with id 73bd32d5-b715-4fab-b17c-d2bcfa5bbc1b -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: technische daten]: - **stromart (v/hz)**: 230 / 50 - **druck (bar/mpa)**: 20 - max. 180 / 2 - max. 18 <!-- text, from page 0 (l=0.064,t=0.853,r=0.740,b=0.939), with id 9a59049a-e149-4a29-936e-4e9f3287c688 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer]: <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.626,b=0.981), with id cde33419-e0e8-43b9-80bd-91873ec28e1d -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page number]: 5/14 <!-- page_number, from page 0 (l=0.931,t=0.972,r=0.959,b=0.980), with id c220d0d5-e779-4c5e-9bfc-c40591b05cbb -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header]: 26/04/2025, 18:05 <!-- page_header, from page 1 (l=0.039,t=0.019,r=0.147,b=0.027), with id 33b3d629-f6f4-436e-8c5e-4a920a03fb51 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: __product_7__ home | kärcher]: this is a page header indicating the title of a product, specifically the "__product_7__ home" by kärcher. <!-- page_header, from page 1 (l=0.484,t=0.019,r=0.672,b=0.028), with id 004386be-2519-481f-a8bf-f500439fe918 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: document details]: - **fördermenge (l/h)**: max. 600 - **flächenleistung (m²/h)**: 60 - **zulauftemperatur (°c)**: max. 60 - **anschlussleistung (kw)**: 3 - **anschlusskabel (m)**: 5 - **farbe**: gelb - **gewicht ohne zubehör (kg)**: 17,3 - **gewicht inkl. verpackung (kg)**: 24,9
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: document details]: - **gewicht inkl. verpackung (kg)**: 24,9 - **abmessungen (l × b × h) (mm)**: 458 × 330 × 666 <!-- key_value, from page 1 (l=0.079,t=0.046,r=0.656,b=0.383), with id a5cbc49f-259b-43d8-afe4-4122b7d1d94c -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: lieferumfang]: - home kit: flächenreiniger t 7, stein- und fassadenreiniger, 3in1, 1 l - hochdruckpistole: g 180 q - dreckfräser - hd-schlauch: 10 m, premiumflex - adapter gartenschlauchanschluss a3/4" <!-- text, from page 1 (l=0.064,t=0.399,r=0.609,b=0.589), with id 971dd211-1a6b-4738-92da-1feaf4e6ce9c -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: ausstattung]: - vario power jet - integriertes aufbewahrungsnetz - geräteseitiges quick connect - reinigungsmittel-einsatz über: plug 'n' clean-system - teleskopgriff - wassergekühlter motor
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: ausstattung]: - teleskopgriff - wassergekühlter motor - integrierter wasserfilter <!-- text, from page 1 (l=0.062,t=0.626,r=0.489,b=0.886), with id 3679a92a-e76b-4926-9818-6b7e2ad114fc -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer]: [ <!-- page_footer, from page 1 (l=0.039,t=0.972,r=0.626,b=0.982), with id c3e907b3-522b-401f-8f85-284434afd015 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer/header 3: page number]: 6/14 <!-- page_number, from page 1 (l=0.931,t=0.972,r=0.959,b=0.980), with id b1c5e40f-9f17-440f-8804-859f2c79a1dd -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header]: 26/04/2025, 18:05 <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.147,b=0.027), with id 97109ec7-59a1-478a-ab83-8a85be65a0a8 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: __product_7__ home | kärcher]: this is a page header indicating the product name "__product_7__ home" by the brand "kärcher". <!-- page_header, from page 0 (l=0.484,t=0.019,r=0.674,b=0.028), with id 3967f212-be56-416d-abe2-dbca8f96a932 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: the image is a simple black and white icon. it features a stylized representation of a computer screen with a document on it. the document is depicted with a few horizontal lines, suggesting text, and a folded corner, indicating a page. below the icon, there is text in german: "online lesen," which
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: there is text in german: "online lesen," which translates to "read online" in english. this suggests that the icon is likely used to indicate an option to read a document or publication online. <!-- figure, from page 0 (l=0.064,t=0.045,r=0.304,b=0.207), with id 0afe9586-bd25-4f88-a3dc-e3682298fe81
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: with id 0afe9586-bd25-4f88-a3dc-e3682298fe81 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: anwendungsgebiete]: - terrasse - zäune - garten- und steinmauern - flächen rund um haus und garten - autos - wohnmobile - fahrräder - motorräder und -roller - gartengeräte und -werkzeuge
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: anwendungsgebiete]: - gartengeräte und -werkzeuge - garten-/terrassen-/balkonmöbel <!-- text, from page 0 (l=0.064,t=0.530,r=0.356,b=0.925), with id f0f34efc-9fac-4d64-a200-265dac57e5f9 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer]: [ <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.626,b=0.981), with id fd6f71ae-6006-438d-bdc4-ccf60fcc7f63 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page number]: 9/14 <!-- page_number, from page 0 (l=0.931,t=0.972,r=0.959,b=0.980), with id 8d25db17-37e7-4007-8211-a098adeddc01 --> ---
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: kärcher logo]: the image displays the kärcher logo. it features the brand name "kärcher" in bold, black uppercase letters. below the text, there is a solid yellow horizontal line. the logo is simple and uses a clean, modern font, emphasizing the brand's identity. <!-- page_header, from page 0
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: kärcher logo]: brand's identity. <!-- page_header, from page 0 (l=0.062,t=0.031,r=0.223,b=0.063), with id 828975e1-8dd2-4054-b07a-6d651450581b -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: k 7 power flex]: für mehr power: der __product_7__-hochdruckreiniger mit premiumflex-schlauch, g 180 q-pistole, für hartnäckige verschmutzungen auf terrassen, wegen und autos geeignet. <!-- text, from page 0 (l=0.064,t=0.080,r=0.927,b=0.148), with id e357413c-a32e-4414-92a7-c8deadcb775a -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: the image shows a pressure washer, specifically the kärcher k7 model. it is predominantly yellow with black accents. the device is designed for high-pressure cleaning tasks and features a sturdy handle for easy maneuverability. it has large wheels for transport and a hose reel for convenient storage
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: transport and a hose reel for convenient storage of the hose.
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description/header 3: key features:]: - **model**: k7 - **brand**: kärcher - **color**: yellow and black - **components**: - main unit with a handle and wheels - two detachable nozzles/lances for different cleaning tasks
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description/header 3: design details:]: - **main unit**: - the body is primarily yellow with black sections. - the kärcher logo is visible on the front. - the handle is ergonomically designed for easy grip. - the unit has a hose reel for organizing the hose neatly. - **nozzles**: - two black nozzles are shown in front of the main unit.
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description/header 3: design details:]: - they are designed to attach to the main unit for various cleaning applications.
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description/header 3: design details:]: this pressure washer is suitable for heavy-duty cleaning tasks, such as washing vehicles, driveways, and outdoor surfaces. <!-- figure, from page 0 (l=0.066,t=0.192,r=0.934,b=0.866), with id 7ef9330e-2aae-47c2-8a0c-98bcffdeb286 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: price information]: - **price**: 504,99 € - **includes**: inkl. mwst. - **delivery**: kostenlose lieferung ab 50 € <!-- text, from page 0 (l=0.087,t=0.882,r=0.404,b=0.932), with id 5c69ee43-47ab-4dc3-8122-e4d219dcc599 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer]: [ <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.587,b=0.981), with id b09fbb3d-9523-47b4-b92d-ff9a5792ab8c -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header]: - **date and time**: 26/04/2025, 18:02 - **product**: __product_7__ | kärcher <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.654,b=0.028), with id bda16bd9-0758-4dff-aba9-b7248354d198 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header/header 3: page number]: 1/15 <!-- page_number, from page 0 (l=0.932,t=0.972,r=0.959,b=0.980), with id f72ccc29-5b55-4e16-9e70-5d544bb42a11 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header]: 26/04/2025, 18:02 <!-- page_header, from page 1 (l=0.039,t=0.019,r=0.149,b=0.027), with id 29d70f8e-ace8-40d4-bb96-35ffd9be6038 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: __product_7__ | kärcher]: this is a page header indicating the title "__product_7__" associated with the brand "kärcher". <!-- page_header, from page 1 (l=0.504,t=0.019,r=0.654,b=0.028), with id f2902769-9770-4a00-a17f-149a9541af7e -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: key-value information]: - **lieferbar in**: 2-3 werktagen - **bestellnummer**: 1.317-300.0 <!-- key_value, from page 1 (l=0.087,t=0.037,r=0.300,b=0.069), with id 0f534138-95e2-4173-8626-490631fa9bf2 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: händlersuche <!-- text, from page 1 (l=0.087,t=0.112,r=0.191,b=0.122), with id 2815a31f-8b2d-4b34-921c-246bf30cc160 -->/header 3: form field]: - **label**: ort oder plz - **input field**: empty (no text entered) <!-- form, from page 1 (l=0.086,t=0.125,r=0.390,b=0.163), with id 5dfffa2c-9cc0-4d12-81d8-2a599cc6bd63 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: figure description]: the image displays a rating system with the following details: - **stars**: there are 4.5 out of 5 stars filled in yellow, indicating a high rating. - **numerical rating**: the text "4.7" is shown next to the stars, representing the average rating.
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: figure description]: - **number of reviews**: the number "(56)" is displayed, indicating that 56 reviews have contributed to this rating.
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: figure description]: - **call to action**: the text "jetzt produkt bewerten" is present, which translates to "rate the product now" in english. this suggests an invitation for users to submit their own ratings. <!-- figure, from page 1 (l=0.099,t=0.196,r=0.499,b=0.218), with id 4283abc4-b315-40af-9dc1-3934c117ff2c -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: produkt vergleichen]: - the text is in german and translates to "compare product" in english. - the text appears to be a clickable element, possibly a button or link, indicated by the arrow symbol (`>`). <!-- text, from page 1 (l=0.084,t=0.255,r=0.255,b=0.268), with id 5edb5fc0-3764-4e45-aded-bd6ff45751ba -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: benötigen sie hilfe?]: hotline: +49 7195 903 0 <!-- text, from page 1 (l=0.087,t=0.308,r=0.270,b=0.332), with id a8945087-836f-4d76-b837-c42a0b99a36d -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text]: mit dem hochdruckreiniger __product_7__ lässt sich jede oberfläche mit passendem druck reinigen. um den richtigen druck zu finden, unterstützt der in der kärcher home & garden app integrierte anwendungsberater den nutzer mit praktischen tipps zu jeder reinigungssituation und jedem reinigungsobjekt
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text]: reinigungssituation und jedem reinigungsobjekt – für perfekte reinigungsergebnisse. der __product_7__ ist mit einem wassergekühlten motor ausgestattet und wurde gebaut für häufige reinigungseinsätze und starke verschmutzungen, wie man sie zum beispiel von wegen, schwimmbecken, fahrrädern oder
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text]: von wegen, schwimmbecken, fahrrädern oder großen autos kennt. das reichhaltige ausstattungspaket reicht von einer pistole mit praktischem quick connect-anschluss über einen premiumflex-hochdruckschlauch und einen zuverlässigen wasserfilter zum schutz der pumpe bis zu einem vario power-strahlrohr
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text]: der pumpe bis zu einem vario power-strahlrohr (vps) sowie einem dreckfräser mit rotierendem punktstrahl. die druckeinstellung am vps lässt sich buchstäblich im handumdrehen variieren, und der dreckfräser macht selbst hartnäckigsten verschmutzungen den garaus. weitere ausstattungsdetails sind das
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text]: den garaus. weitere ausstattungsdetails sind das plug 'n' clean-reinigungsmittelsystem, der aluminium-teleskopgriff und die parkposition für griffbereites zubehör. <!-- text, from page 1 (l=0.064,t=0.445,r=0.926,b=0.609), with id bfc84457-86eb-4293-8f24-a47185726d50 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: merkmale und vorteile]: the text in the image reads "merkmale und vorteile," which translates to "features and benefits" in english. <!-- text, from page 1 (l=0.064,t=0.636,r=0.281,b=0.646), with id 6f424b12-1184-4207-8b86-b98f156317f6 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer]: <!-- page_footer, from page 1 (l=0.039,t=0.972,r=0.587,b=0.981), with id 9349a566-c6b8-4971-95cf-2d6ab4dbc8a1 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer/header 3: page header]: - **date and time**: 26/04/2025, 18:02 - **title**: __product_7__ | kärcher <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.654,b=0.027), with id be6d4c6a-5f65-49b1-b38e-13f8e3d7c342 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: the image shows a hand placing a container into a slot on a kärcher cleaning device. the container is labeled with the text "bring back the wow" and "clean maintain." the kärcher logo is visible on the container. the device has a black and yellow color scheme, typical of kärcher products. the hand
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: scheme, typical of kärcher products. the hand is wearing a gray sleeve.
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: below the image, there is a caption in german: "plug 'n' clean – das kärcher reinigungsmittelsystem," which translates to "plug 'n' clean – the kärcher cleaning agent system." this suggests that the system allows for easy insertion and use of cleaning agents with the device. <!-- figure, from page
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: agents with the device. <!-- figure, from page 0 (l=0.062,t=0.031,r=0.935,b=0.663), with id a293dc70-be80-41f6-bb46-053a3154329b -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: schnell, einfach, komfortabel]: dank plug 'n' clean lässt sich das reinigungsmittel mit nur einem handgriff bequem austauschen. <!-- text, from page 0 (l=0.064,t=0.669,r=0.914,b=0.694), with id def48216-2327-4027-b384-6dbfc9f26d6f -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: überragende leistung]: - der wassergekühlte motor besticht durch seine besondere langlebigkeit und leistungsfähigkeit. <!-- text, from page 0 (l=0.081,t=0.726,r=0.818,b=0.767), with id f3622845-4e56-47ab-b01d-17e7a02774d9 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: technische daten]: - **stromart (v/hz)**: 230 / 50 - **druck (bar/mpa)**: 20 - max. 180 / 2 - max. 18 <!-- text, from page 0 (l=0.064,t=0.853,r=0.740,b=0.939), with id d9df9c20-310a-4cfb-bb1c-9d0d940ebfa7 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer]: [ <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.587,b=0.981), with id d99a11e0-9337-4927-b58c-3260e7b50a10 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page number]: 5/15 <!-- page_number, from page 0 (l=0.931,t=0.972,r=0.959,b=0.980), with id 848ceb2d-4127-4c8d-99c0-2e622e0895f7 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header]: 26/04/2025, 18:02 <!-- page_header, from page 1 (l=0.039,t=0.019,r=0.149,b=0.027), with id 06ad21bf-ab3a-4e66-95ca-4abef91ab0fd -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header/header 3: __product_7__ | kärcher]: this is a page header indicating the title or section name "__product_7__" associated with the brand "kärcher". <!-- page_header, from page 1 (l=0.504,t=0.019,r=0.654,b=0.028), with id a040ecfb-3edc-4b7a-9b92-5dbf8aa8fa3d -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: document details]: - **fördermenge (l/h)**: max. 600 - **flächenleistung (m²/h)**: 60 - **zulauftemperatur (°c)**: max. 60 - **anschlussleistung (kw)**: 3 - **anschlusskabel (m)**: 5 - **farbe**: gelb - **gewicht ohne zubehör (kg)**: 17,3 - **gewicht inkl. verpackung (kg)**: 23
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: document details]: - **gewicht inkl. verpackung (kg)**: 23 - **abmessungen (l × b × h) (mm)**: 458 x 330 x 660 <!-- key_value, from page 1 (l=0.077,t=0.044,r=0.649,b=0.384), with id 5fbda869-b8f6-4aaa-92bb-a5c48aa62b46 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: lieferumfang]: the text in the crop is "lieferumfang". <!-- text, from page 1 (l=0.064,t=0.399,r=0.189,b=0.413), with id 24670c17-f8fc-4148-9c35-bfc823a08c84 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: document details]: - **hochdruckpistole**: g 180 q - **dreckfräser** - **hd-schlauch**: 10 m, premiumflex - **adapter gartenschlauchanschluss**: a3/4" <!-- text, from page 1 (l=0.084,t=0.432,r=0.402,b=0.553), with id 578732bf-ed52-4653-a235-1bebcf6f0df8 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: features]: - vario power jet - integriertes aufbewahrungsnetz - geräteseitiges quick connect - reinigungsmittel-einsatz über: plug 'n' clean-system - teleskopgriff - wassergkühlter motor
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: features]: - teleskopgriff - wassergkühlter motor - integrierter wasserfilter <!-- text, from page 1 (l=0.084,t=0.622,r=0.489,b=0.850), with id 36c9dea8-1b9d-441a-9f79-e6267ec549e2 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: features/header 3: page footer information]: - **url**: [
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: features/header 3: page footer information]: this url appears to be a link to a product page on the kärcher website, specifically for a high-pressure cleaner model "__product_7__." <!-- page_footer, from page 1 (l=0.039,t=0.972,r=0.587,b=0.982), with id d8b6dce1-b251-4963-ac24-f55991774bf8 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: features/header 3: page number]: 6/15 <!-- page_number, from page 1 (l=0.931,t=0.972,r=0.959,b=0.980), with id 6aea910b-76f3-44ce-bd6a-b125110ad7a7 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header]: - date and time: 26/04/2025, 18:02 - product: __product_7__ | kärcher <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.654,b=0.028), with id 2a52458c-b355-4814-9515-e9ae484eb99c -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: anwendungsgebiete]: - terrasse - zäune - garten- und steinmauern - flächen rund um haus und garten - autos - wohnmobile - fahrräder - motorräder und -roller - gartengeräte und -werkzeuge
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: anwendungsgebiete]: - gartengeräte und -werkzeuge - garten-/terrassen-/balkonmöbel <!-- text, from page 0 (l=0.064,t=0.230,r=0.356,b=0.624), with id 0e68cf0f-3e88-4f51-9671-7e2d361766fd -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: k 7 power flex ersatzteile]: this text appears to be a heading or title related to replacement parts for a product named "__product_7__." <!-- text, from page 0 (l=0.064,t=0.714,r=0.311,b=0.724), with id 8759019e-531f-4127-a4da-d0835885d409 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: kärcher original-ersatzteile]: egal, wo sie ihr kärcher-gerät gekauft haben, sie können sich im reparaturfall an jeden **kärcher-fachhändler** in ihrer nähe wenden. ersatzteile dürfen lediglich von ausgebildetem fachpersonal getauscht werden. bitte beachten sie die [garantiebedingungen](#). <!-- text, from page 0
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: kärcher original-ersatzteile]: [garantiebedingungen](#). <!-- text, from page 0 (l=0.064,t=0.762,r=0.915,b=0.826), with id cb0f9b3f-5d60-4f3e-be15-cf842047ddce -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: home & garden geräte]: - ihr kärcher-gerät können sie über den online-reparaturservice im mykärcher kundenportal einschicken. alternativ können sie ihr ersatzteil einfach und bequem in unserem onlineshop bestellen. <!-- text, from page 0 (l=0.064,t=0.840,r=0.894,b=0.889), with id 2d8f8f48-a9df-43bb-a601-049eabc4a34e -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: professional geräte]: - kleingeräte können sie über das [mykärcher kundenportal](#) einschicken. alternativ können sie ihr ersatzteil einfach und bequem in unserem onlineshop [bestellen](#). <!-- text, from page 0 (l=0.064,t=0.901,r=0.904,b=0.951), with id f1da39f1-dbed-4f5c-ac14-5444309709b8 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer]: [ 9/15 <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.959,b=0.981), with id f36528a5-c759-4859-86e7-c0d730731f16 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer]: ---
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header]: - **date and time**: 26/04/2025, 17:57 - **logo**: kärcher
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page header]: - **logo**: kärcher the image shows the kärcher logo, which is prominently displayed with bold black text on a white background, accompanied by a yellow underline. <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.223,b=0.062), with id b5c20f92-90b4-4cce-a341-cb12dc493235 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: __product_2__ home | kärcher]: this is a page header indicating the product name "__product_2__ home" by the brand "kärcher". <!-- page_header, from page 0 (l=0.455,t=0.019,r=0.703,b=0.028), with id 568caa96-cbfb-423a-8230-382653e1e125 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: k 7 premium power flex home]: für mehr power: __product_2__ home mit premiumflex-schlauch, g 180 q-pistole, vario power-strahlrohr, schlauchtrommel und home kit. für hartnäckige verschmutzungen rund ums haus. <!-- text, from page 0 (l=0.064,t=0.080,r=0.858,b=0.148), with id 654b165d-c9cf-408b-8ee2-707a950e985d -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description]: the image shows a kärcher k7 premium pressure washer set. the main unit is predominantly yellow with black accents and features a handle for easy transport. it has a hose reel on the back and a prominent kärcher logo on the front. the model name "k7 premium" is visible on the side.
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description/header 3: components included:]: 1. **pressure washer unit**: - color: yellow and black - features: handle, hose reel, wheels for mobility 2. **surface cleaner attachment**: - color: yellow and black - purpose: designed for cleaning flat surfaces 3. **two spray lances**: - color: black
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description/header 3: components included:]: 3. **two spray lances**: - color: black - purpose: different nozzles for various cleaning tasks 4. **detergent bottle**: - label: "stone & facade cleaner" - purpose: specialized cleaning solution for stone surfaces
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description/header 3: components included:]: this set is designed for high-performance cleaning, suitable for outdoor surfaces like patios, driveways, and facades. the inclusion of different attachments and a detergent bottle suggests versatility and effectiveness in handling various cleaning tasks. <!-- figure, from page 0
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: description/header 3: components included:]: various cleaning tasks. <!-- figure, from page 0 (l=0.065,t=0.192,r=0.934,b=0.866), with id b784eddf-e48f-45a4-9ab1-177d30baeebb -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: price information]: - **price**: 624,99 € - **includes**: mwst. (vat) - **delivery**: kostenlose lieferung ab 50 € (free delivery from 50 €) <!-- key_value, from page 0 (l=0.087,t=0.882,r=0.404,b=0.932), with id 0791e3d2-41e5-47f4-aba9-ff9e9c94cfce -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page footer]: <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.682,b=0.981), with id 538b1472-4425-496d-b485-fc49e681dcdd -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: page number]: 1/14 <!-- page_number, from page 0 (l=0.932,t=0.972,r=0.959,b=0.980), with id b6047ed6-531d-431b-abef-34df050b5bdc -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: date and time]: - **date**: 26/04/2025 - **time**: 17:57 <!-- page_header, from page 1 (l=0.039,t=0.019,r=0.149,b=0.027), with id 8282b690-5f27-49c5-82ed-68b230224d16 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: __product_2__ home | kärcher]: this is a page header indicating the product name and brand. the text suggests a focus on a specific model of a kärcher product, likely a pressure washer or similar cleaning equipment. <!-- page_header, from page 1 (l=0.455,t=0.019,r=0.703,b=0.028), with id a5710ce6-765c-43e5-938c-c0e502f98fa3 -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: text information]: - lieferbar in 2-3 werktagen - bestellnummer: 1.317-322.0 <!-- key_value, from page 1 (l=0.087,t=0.037,r=0.300,b=0.069), with id ecc2aa53-2dac-4e54-80a6-9f7f93bf471f -->
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: händler suche]: - **ort oder plz**: [ ] (input field)
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: bewertung]: - **sternebewertung**: ★★★★★ - **durchschnittliche bewertung**: 4.8 - **anzahl der bewertungen**: (77) - **aktion**: jetzt produkt bewerten
#
# [header 1: k 7 power flex home <!-- title, from page 0 (l=0.065,t=0.080,r=0.436,b=0.100), with id 7417f6ca-fa9f-401a-9b38-6819c6e6fbec -->/header 2: produktvergleich]: - **produkt vergleichen**: [ ] (expandable section)
#
# ...
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: kraftvolle reinigung]: kraftvolle reinigung, die sie überzeugen wird! der __product_11__ ist der ideale (reinigungs-)partner für häufige einsätze und starke verschmutzungen: mit seinem leistungsstarken, wassergekühlten motor macht er schmutz auf wegen, terrassen, gartengeräten und größeren autos den garaus. um die oberflächen
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: kraftvolle reinigung]: und größeren autos den garaus. um die oberflächen besonders effektiv und schonend zu reinigen, lässt sich das vario power-strahlrohr (vps) durch einfaches drehen verstellen. weitere features sind der dreckfräser mit rotierendem punktstrahl, der auch bei hartnäckigem schmutz für kompromisslosen
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: kraftvolle reinigung]: auch bei hartnäckigem schmutz für kompromisslosen reinigungserfolg sorgt. ein eingebauter wasserfilter schützt die pumpe zudem zuverlässig vor schmutzpartikeln. zudem können alle enthaltenen zubehör einfach direkt am gerät verstaut werden. <!-- text, from page 1 (l=0.064,t=0.542,r=0.931,b=0.644),
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: kraftvolle reinigung]: from page 1 (l=0.064,t=0.542,r=0.931,b=0.644), with id 72cf1948-fe52-4d3c-9293-30035aacb8d9 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page footer]: [ <!-- page_footer, from page 1 (l=0.039,t=0.972,r=0.554,b=0.981), with id 94c04ad4-9aba-4f5b-be8c-0eb04cc2e081 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page footer/header 3: page number]: 2/13 <!-- page_number, from page 1 (l=0.931,t=0.972,r=0.959,b=0.980), with id 1cbb1a02-3c0d-4ba8-90c8-be4ea3486be7 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page header]: - **date and time**: 26/04/2025, 18:11 this crop from a document header displays a date and time, formatted as day/month/year and hour:minute. <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.146,b=0.027), with id 5d6db435-d967-4e1c-8249-f62a6937a247 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: __product_11__ | kärcher]: this is a page header indicating a model or product name associated with the brand kärcher. <!-- page_header, from page 0 (l=0.519,t=0.019,r=0.636,b=0.027), with id da34eba2-0016-40f3-928c-a316ebfc5307 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: description]: the image shows a pressure washer viewed from the back. it features a sturdy, black plastic frame with two large wheels at the bottom for mobility. the handle is positioned at the top, designed for easy transportation.
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: description/header 3: key features:]: - **hose and cable management**: - a coiled hose is neatly wrapped around the central part of the frame. - an electrical cable is also visible, organized to prevent tangling. - **components**: - a spray gun is attached to the side, with a yellow trigger for operation.
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: description/header 3: key features:]: - the lance is secured on the opposite side, ready for use. - **design**: - the overall design is compact and efficient, allowing for easy storage and maneuverability. - the color scheme is primarily black with some yellow accents, typical for many pressure washers.
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: description/header 3: key features:]: this description provides a comprehensive understanding of the pressure washer's design and features without needing to view the original image. <!-- figure, from page 0 (l=0.061,t=0.034,r=0.934,b=0.649), with id a80b3062-93e1-4648-8168-9100eee070a6 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: sauber aufgeräumt]: schlauch, strahlrohre, pistole und kabel lassen sich direkt am gerät verstauen. <!-- text, from page 0 (l=0.064,t=0.650,r=0.647,b=0.681), with id f514696f-c6fc-4410-acba-f686d6576536 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: quick connect-system]: - der hochdruckschlauch lässt sich schnell und bequem in das gerät und in die pistole ein- und wieder ausklicken. das spart zeit und aufwand. <!-- text, from page 0 (l=0.081,t=0.711,r=0.853,b=0.762), with id 85899379-d98e-41d1-b0d3-8d44c3e626c6 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: technische daten]: - stromart (v/hz): 230 / 50 - druck (bar/mpa): 20 - max. 180 / 2 - max. 18 <!-- key_value, from page 0 (l=0.064,t=0.848,r=0.740,b=0.935), with id b04c19d3-1240-4c12-a526-dd46d63716d6 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page footer]: [ <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.554,b=0.981), with id 557cc6d7-3b7f-4777-a5bc-086d8d905e65 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page header]: - date: 26/04/2025 - time: 18:11 <!-- page_header, from page 1 (l=0.039,t=0.019,r=0.146,b=0.027), with id 3b8c7c53-8277-49ab-9424-1e04fb88eb9b -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page header/header 3: __product_11__ | kärcher]: this is a page header containing the text "__product_11__ | kärcher". <!-- page_header, from page 1 (l=0.520,t=0.019,r=0.636,b=0.028), with id adfca83b-3ad1-4001-a242-f3e5674e162b -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: document details]: - **fördermenge (l/h)**: max. 600 - **flächenleistung (m²/h)**: 60 - **zulauftemperatur (°c)**: max. 60 - **anschlussleistung (kw)**: 3 - **anschlusskabel (m)**: 5 - **farbe**: gelb - **gewicht ohne zubehör (kg)**: 17,2 - **gewicht inkl. verpackung (kg)**: 21,2
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: document details]: - **gewicht inkl. verpackung (kg)**: 21,2 - **abmessungen (l × b × h) (mm)**: 369 x 355 x 946 <!-- key_value, from page 1 (l=0.079,t=0.045,r=0.655,b=0.385), with id 770be7a2-6130-4c92-82fb-21494e8860c7 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: lieferumfang]: - hochdruckpistole: g 180 q - dreckfräser - hd-schlauch: 10 m - adapter gartenschlauchanschluss a3/4" <!-- text, from page 1 (l=0.064,t=0.399,r=0.402,b=0.553), with id 402d5136-538b-47ee-a788-48f563c9a045 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: ausstattung]: - vario power jet - reinigungsmittelansatz über: ansaugschlauch - wassergekühlter motor - integrierter wasserfilter <!-- text, from page 1 (l=0.062,t=0.589,r=0.450,b=0.742), with id 606a04a0-0b20-488d-a2e0-4eb3f1658365 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: description]: the image is a stylized representation of the european union (eu) flag. it features a blue background with a circle of twelve yellow stars. the stars are evenly spaced and arranged in a circular pattern, symbolizing unity among the peoples of europe. the flag is depicted in a unique shape,
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: description]: europe. the flag is depicted in a unique shape, resembling a speech bubble or a flag with a pointed bottom edge, rather than the traditional rectangular form. this design choice may suggest communication or dialogue, possibly indicating a theme of discussion or interaction related to the eu. <!--
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: description]: discussion or interaction related to the eu. <!-- figure, from page 1 (l=0.064,t=0.769,r=0.396,b=0.920), with id 61f0aae9-9fd7-43cc-a8c7-0ae70f33651d -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: made in europe]: the text "made in europe" is presented in a straightforward manner, indicating the origin of a product or item. there are no additional elements such as checkboxes, tables, or equations in this crop. <!-- text, from page 1 (l=0.096,t=0.936,r=0.365,b=0.963), with id
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: made in europe]: page 1 (l=0.096,t=0.936,r=0.365,b=0.963), with id bcf268d8-7458-42a0-ac66-db9f0cf0d547 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page footer]: [ <!-- page_footer, from page 1 (l=0.039,t=0.972,r=0.554,b=0.981), with id f5c464f2-e218-4b17-82b0-1fbf0bbb7da6 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page number]: 6/13 <!-- page_number, from page 1 (l=0.931,t=0.972,r=0.959,b=0.980), with id 9056a555-af44-43d4-84cc-798362552a0f -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page header]: - date: 26/04/2025 - time: 18:11 <!-- page_header, from page 0 (l=0.039,t=0.019,r=0.146,b=0.027), with id c8640f6f-75c3-4339-8dc0-b26858aeb63d -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page header/header 3: page header]: **__product_11__ | kärcher**
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page header/header 3: page header]: this is a cropped section from a document header, displaying the text "__product_11__ | kärcher". the text appears to be a model or product name associated with the brand kärcher. <!-- page_header, from page 0 (l=0.520,t=0.019,r=0.636,b=0.028), with id c18796c6-8e9e-42bf-af7c-a071e9b8661a -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: videos]: the crop contains the text "videos" formatted as a header. <!-- page_header, from page 0 (l=0.064,t=0.033,r=0.125,b=0.043), with id a0a26a98-4e9a-4406-b712-2828760466a8 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: anwendungsgebiete]: - garten- und steinmauern - außentreppen - flächen rund um haus und garten - garten-/terrassen-/balkonmöbel - gartengeräte und -werkzeuge - autos - wohnmobile - motorräder und -roller
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: anwendungsgebiete]: - autos - wohnmobile - motorräder und -roller - fahrräder <!-- text, from page 0 (l=0.064,t=0.312,r=0.358,b=0.669), with id 2f6eaf25-d8cd-4e71-817b-07c9a51a5005 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: __product_11__ ersatzteile]: the text in the image reads "__product_11__ ersatzteile". <!-- text, from page 0 (l=0.064,t=0.761,r=0.246,b=0.771), with id b642ee77-cf76-4034-8c39-6f7f07acd89a -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: kärcher original-ersatzteile]: egal, wo sie ihr kärcher-gerät gekauft haben, sie können sich im reparaturfall an jeden **kärcher-fachhändler** in ihrer nähe wenden. ersatzteile dürfen lediglich von ausgebildetem fachpersonal getauscht werden. bitte beachten sie die [garantiebedingungen](#). <!-- text, from page 0
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: kärcher original-ersatzteile]: [garantiebedingungen](#). <!-- text, from page 0 (l=0.064,t=0.808,r=0.915,b=0.873), with id 9db13d7e-1d5c-49a3-8c19-0eeeca10b744 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: home & garden geräte]: - ihr kärcher-gerät können sie über den online-reparaturservice im mykärcher kundenportal einschicken. alternativ können sie ihr ersatzteil einfach und bequem in unserem onlineshop bestellen. <!-- text, from page 0 (l=0.064,t=0.886,r=0.894,b=0.935), with id e0ade55c-272f-4ced-90f5-ae8e71ec252a -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page footer]: link: [ <!-- page_footer, from page 0 (l=0.039,t=0.972,r=0.554,b=0.981), with id d218f170-99ba-440d-aeae-35d12e100cf7 -->
#
# [header 1: k 7 smart control flex eco!booster <!-- title, from page 0 (l=0.065,t=0.080,r=0.681,b=0.100), with id 430bb76c-671d-48bf-8513-c1f8d83bec18 -->/header 2: page number]: 9/13 <!-- page_number, from page 0 (l=0.931,t=0.972,r=0.959,b=0.980), with id 06dbba8b-3e41-420b-9b23-d781ebadb63f -->

# %%
from langchain_ibm import WatsonxEmbeddings


embed_params = {}

watsonx_embedding = WatsonxEmbeddings(
    model_id="ibm/granite-embedding-278m-multilingual",
    url= WX_API_URL,
    project_id=WX_PROJECT_ID,
    apikey=WX_API_KEY,
    params=embed_params,
)

# %%
from langchain_chroma import Chroma


local_vector_db = Chroma.from_documents(
    collection_name="my_collection",
    embedding=watsonx_embedding,
    persist_directory="my_vector_db", # This will save the vector database to disk! Delete it if you want to start fresh.
    documents=docs,
    
)

# %%
# Use the vectorstore as a retriever
retriever = local_vector_db.as_retriever(
    search_type="similarity",
    search_kwargs={
        "k": 3,
    }
)

# %%
# Retrieve the most similar text
retrieved_documents = retriever.invoke("What is the price in € of the product K 7 Power Flex Home")

for document in retrieved_documents:
    print(f"{'#' * 80}\nID: {document.id}")
    first_n_of_content = document.page_content[:500].replace('\n\n', ' ')
    print(f"Content: {first_n_of_content}\n")
# Out:
# ################################################################################
# ID: 81a3864a-d4f6-4692-8776-2a2a2c8e8735
# Content: [header 1: k 7 power flex home /header 2: price information]:
# - **price**: 504,99 €
# - **includes**: inkl. mwst.
# - **delivery**: kostenlose lieferung ab 50 €
#
# ################################################################################
# ID: 61688763-bb05-490e-9e8d-be75eed289a5
# Content: [header 1: k 7 power flex home /header 2: price information]:
# - **price**: 694,99 €
# - **includes**: mwst. (vat)
# - **delivery**: kostenlose lieferung ab 50 € (free delivery from 50 €)
#
# ################################################################################
# ID: a53525f5-9676-4eac-86e9-d4c5661ca1a2
# Content: [header 1: k 7 power flex home /header 2: price information]:
# - **price**: 624,99 €
# - **includes**: mwst. (vat)
# - **delivery**: kostenlose lieferung ab 50 € (free delivery from 50 €)

# %%
from langchain.prompts import PromptTemplate

template = """You are an assistant helping to complete missing fields in a product database by extracting accurate information from documentation.

Each question corresponds to a missing field in the product's entry (e.g., price, description, accessories). Use the retrieved context to find and return the correct value.

If the context does not contain the necessary information, respond with "Unknown". Keep answers factual, concise, and suitable for filling into a CSV cell. Do not speculate or include explanations.

Question:
{question}

Context: 
{context}

Answer:
"""
prompt = PromptTemplate.from_template(template)

# %%
prompt.invoke(
    input={
        "question": "What is the price in € of the product K 7 Premium Power Flex?",
        "context": retrieved_documents[0].page_content,
        
    }
)
# Out:
# StringPromptValue(text='You are an assistant helping to complete missing fields in a product database by extracting accurate information from documentation.\n\nEach question corresponds to a missing field in the product\'s entry (e.g., price, description, accessories). Use the retrieved context to find and return the correct value.\n\nIf the context does not contain the necessary information, respond with "Unknown". Keep answers factual, concise, and suitable for filling into a CSV cell. Do not speculate or include explanations.\n\nQuestion:\nWhat is the price in € of the product K 7 Premium Power Flex?\n\nContext: \n[header 1: k 7 power flex home /header 2: price information]: \n- **price**: 504,99 €\n- **includes**: inkl. mwst.\n- **delivery**: kostenlose lieferung ab 50 €\n\nAnswer:\n')

# %%
question = "What is the price in € of the product K 7 Power Flex Home?"

retrieved_docs = local_vector_db.similarity_search(question)
docs_content = "\n\n".join(f"Document {i+1}:\n{doc.page_content}" for i, doc in enumerate(retrieved_docs))
formated_prompt = prompt.invoke({"question": question, "context": docs_content})

print(formated_prompt.to_string()[:1000])
# Out:
# You are an assistant helping to complete missing fields in a product database by extracting accurate information from documentation.
#
# Each question corresponds to a missing field in the product's entry (e.g., price, description, accessories). Use the retrieved context to find and return the correct value.
#
# If the context does not contain the necessary information, respond with "Unknown". Keep answers factual, concise, and suitable for filling into a CSV cell. Do not speculate or include explanations.
#
# Question:
# What is the price in € of the product K 7 Power Flex Home?
#
# Context:
# Document 1:
# [header 1: k 7 power flex home /header 2: price information]:
# - **price**: 504,99 €
# - **includes**: inkl. mwst.
# - **delivery**: kostenlose lieferung ab 50 €
#
# Document 2:
# [header 1: k 7 power flex home /header 2: price information]:
# - **price**: 694,99 €
# - **includes**: mwst. (vat)
# - **delivery**: kostenlose lieferung ab 50 € (free delivery from 50 €)
#
# Document 3:
# [header 1: k 7 power flex home /h

# %%
answer = llm.invoke(formated_prompt)

print(answer)
# Out:
# The price in € of the product K 7 Premium Power Flex Home is 504.99.

# %%
df = pd.read_csv(r"C:\Users\charl\Documents\CBS\Code Projects_Python\AIML25\AIML25_Project\data\SAP_Produktstammdaten_vfinal.csv", sep=",")

# %%
print(df["Produktname"].unique())
# Out:
# ['K 7 Premium Smart Control Flex eco!B'
#  'K 7 Premium Smart Control Flex Home' 'K 7 Premium Power Flex'
#  'K 7 Premium Power Flex Home' 'K 7 Premium Smart Control Flex'
#  'K 7 Smart Control Flex eco!Booster' 'K 7 Smart Control Flex Home'
#  'K 7 Power Flex' 'K 7 Power Flex Home' 'K 7 Smart Control Flex'
#  'K 7 WCM Premium Home' 'K 7 WCM' 'K 7 WCM Car&Home' 'K 7 WCM FJ'
#  'K 7 WCM Premium' 'K 5 Premium Smart Control Flex eco!Booster'
#  'K 5 Power Control Flex' 'K 5 Power Control Flex Home' 'K 5 WCM'
#  'K 5 WCM Premium' 'K 5 WCM Premium Home' 'K 5 Classic'
#  'K 5 Classic Car & Home' 'K 5 Classic Home' 'K 5 FJ' 'K 5 FJ Home'
#  'K 5 Premium Smart Control Flex Home'
#  'K 5 Power Control Flex Home&Brush Anniversary Edition'
#  'K 5 Premium Power Control Flex' 'K 5 Premium Power Control Flex Home'
#  'K 5 Premium Smart Control Flex' 'K 5 Smart Control Flex eco!Booster'
#  'K 4 Premium Power Control Flex' 'K 4 FJ' 'K 4 FJ Home' 'K 4 WCM Premium'
#  'K 4 Classic' 'K 4 Classic Car' 'K 4 Classic Home' 'K 4 WCM Premium Home'
#  'K Silent Anniversary Edition' 'K Silent eco!Booster'
#  'K 4 Power Control Flex' 'K 4 Power Control Flex Home'
#  'K 4 Premium Power Control Flex Home' 'K 4 WCM' 'K 3 Power Control'
#  'K 3 Classic' 'K 3 Classic Car' 'K 3 FJ' 'K 3 FJ Home'
#  'K 3 Horizontal Plus Home' 'K 3 Power Control Home T 5'
#  'K 3 Premium Power Control' 'K 3 Horizontal Plus' 'K 2 Premium FJ'
#  'K 2 Battery' 'K 2 Classic' 'K 2 Power Control'
#  'K 2 Power Control Car & Home' 'K 2 Premium FJ Home'
#  'K 2 Premium Horizontal VPS Home' 'K 2 Battery Set' 'K 2 Horizontal VPS'
#  'K 2 Power Control Home' 'K 2 Universal Edition'
#  'K 2 Universal Edition Home' 'K Mini']

# %%
def query_product_info(product_name, field, markdown_chunks):
    relevant_docs = find_relevant_docs(product_name, markdown_chunks)
    if not relevant_docs:
        return "No documentation found mentioning this product.", ""

    context = "\n\n".join([doc.page_content for doc in relevant_docs])
    context = context[:8000]  # Truncate for token limit

    prompt = SYSTEM_PROMPT.format(
        product_name=product_name,
        context=context,
        field=field
    )

    response = model.generate(prompt)
    answer = response["results"][0]["generated_text"].strip()
    return answer, context

# %%
missing_fields = []

for idx, row in df.iterrows():
    product_name = row["Produktname"]
    
    for field in df.columns:
        value = row[field]
        if pd.isna(value) or str(value).strip().lower() in ["", "n/a", "–", "nicht verfügbar", "unbekannt", "nicht angegeben"]:
            missing_fields.append((idx, product_name, field))

# Display all missing values
for idx, product_name, field in missing_fields:
    print(f"Row {idx} – {product_name} is missing: {field}")
# Out:
# Row 2 – K 7 Premium Power Flex is missing: Preis (€ inkl. MwSt.)
# Row 25 – K 5 FJ Home is missing: Preis (€ inkl. MwSt.)
# Row 29 – K 5 Premium Power Control Flex Home is missing: Preis (€ inkl. MwSt.)
# Row 35 – K 4 WCM Premium is missing: Anschlusskabel (m)
# Row 36 – K 4 Classic is missing: Preis (€ inkl. MwSt.)
# Row 36 – K 4 Classic is missing: Lieferzeit
# Row 38 – K 4 Classic Home is missing: Preis (€ inkl. MwSt.)
# Row 38 – K 4 Classic Home is missing: Lieferzeit
# Row 39 – K 4 WCM Premium Home is missing: Anschlusskabel (m)
# Row 47 – K 3 Classic is missing: Preis (€ inkl. MwSt.)
# Row 47 – K 3 Classic is missing: Lieferzeit
# Row 54 – K 3 Horizontal Plus is missing: Preis (€ inkl. MwSt.)
# Row 54 – K 3 Horizontal Plus is missing: Lieferzeit
# Row 56 – K 2 Battery is missing: Flächenleistung (m²/h)
# Row 56 – K 2 Battery is missing: Anschlussleistung (kW)
# Row 61 – K 2 Premium Horizontal VPS Home is missing: Anschlussleistung (kW)
# Row 61 – K 2 Premium Horizontal VPS Home is missing: Anschlusskabel (m)
# Row 62 – K 2 Battery Set is missing: Preis (€ inkl. MwSt.)
# Row 62 – K 2 Battery Set is missing: Lieferzeit
# Row 62 – K 2 Battery Set is missing: Flächenleistung (m²/h)
# Row 62 – K 2 Battery Set is missing: Anschlussleistung (kW)
# Row 65 – K 2 Universal Edition is missing: Anschlusskabel (m)
# Row 66 – K 2 Universal Edition Home is missing: Anschlusskabel (m)
# Row 67 – K Mini is missing: Preis (€ inkl. MwSt.)
# Row 67 – K Mini is missing: Lieferzeit

# %%
def find_relevant_docs(product_name, field, markdown_chunks):
    field_lower = field.lower()
    product_lower = product_name.lower()

    relevant = []
    for chunk in markdown_chunks:
        text = chunk.page_content.lower()
        
        if product_lower in text and field_lower in text:
            relevant.append(chunk)

    return relevant
