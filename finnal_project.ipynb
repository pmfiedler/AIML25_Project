# %% [markdown]
# ## 1. LLM

# %%
# imports for the project

import pandas as pd
from decouple import config
from ibm_watsonx_ai import APIClient
from ibm_watsonx_ai import Credentials
from ibm_watsonx_ai.foundation_models import ModelInference
from dotenv import load_dotenv
from sklearn.metrics import classification_report 
from tqdm import tqdm
from ibm_watsonx_ai.foundation_models.schema import TextGenParameters

# %%
import os
print(os.path.exists(".env"))
# Out:
# True

# %%
# Load .env file
load_dotenv()

# Get the API key
WX_API_KEY = os.getenv('WX_API_KEY')

if WX_API_KEY:
    print("API Key Loaded Successfully")
else:
    print("API Key Not Found! Check your .env file.")
# Out:
# API Key Loaded Successfully

# %%
credentials = Credentials(
    url = "https://us-south.ml.cloud.ibm.com",
    api_key = WX_API_KEY,
)

client = APIClient(
    credentials=credentials, 
    project_id="c109b911-7caf-4fe6-b111-b766c2039951"
)

# %% [markdown]
# ## 2. Load csv file

# %%
df = pd.read_csv(r"C:\Users\charl\Documents\CBS\Code Projects_Python\AIML25\AIML25_Project\data\SAP_Produktstammdaten_vfinal.csv", sep=",")

# %%
missing_fields = []

for idx, row in df.iterrows():
    product_name = row["Produktname"]
    
    for field in df.columns:
        value = row[field]
        if pd.isna(value) or str(value).strip().lower() in ["", "n/a", "–", "nicht verfügbar", "unbekannt", "nicht angegeben"]:
            missing_fields.append((idx, product_name, field))

# Display all missing values
for idx, product_name, field in missing_fields:
    print(f"Row {idx} – {product_name} is missing: {field}")
# Out:
# Row 2 – K 7 Premium Power Flex is missing: Preis (€ inkl. MwSt.)
# Row 25 – K 5 FJ Home is missing: Preis (€ inkl. MwSt.)
# Row 29 – K 5 Premium Power Control Flex Home is missing: Preis (€ inkl. MwSt.)
# Row 35 – K 4 WCM Premium is missing: Anschlusskabel (m)
# Row 36 – K 4 Classic is missing: Preis (€ inkl. MwSt.)
# Row 36 – K 4 Classic is missing: Lieferzeit
# Row 38 – K 4 Classic Home is missing: Preis (€ inkl. MwSt.)
# Row 38 – K 4 Classic Home is missing: Lieferzeit
# Row 39 – K 4 WCM Premium Home is missing: Anschlusskabel (m)
# Row 47 – K 3 Classic is missing: Preis (€ inkl. MwSt.)
# Row 47 – K 3 Classic is missing: Lieferzeit
# Row 54 – K 3 Horizontal Plus is missing: Preis (€ inkl. MwSt.)
# Row 54 – K 3 Horizontal Plus is missing: Lieferzeit
# Row 56 – K 2 Battery is missing: Flächenleistung (m²/h)
# Row 56 – K 2 Battery is missing: Anschlussleistung (kW)
# Row 61 – K 2 Premium Horizontal VPS Home is missing: Anschlussleistung (kW)
# Row 61 – K 2 Premium Horizontal VPS Home is missing: Anschlusskabel (m)
# Row 62 – K 2 Battery Set is missing: Preis (€ inkl. MwSt.)
# Row 62 – K 2 Battery Set is missing: Lieferzeit
# Row 62 – K 2 Battery Set is missing: Flächenleistung (m²/h)
# Row 62 – K 2 Battery Set is missing: Anschlussleistung (kW)
# Row 65 – K 2 Universal Edition is missing: Anschlusskabel (m)
# Row 66 – K 2 Universal Edition Home is missing: Anschlusskabel (m)
# Row 67 – K Mini is missing: Preis (€ inkl. MwSt.)
# Row 67 – K Mini is missing: Lieferzeit

# %% [markdown]
# ## 3. Load markdown data

# %%
file_path= r"C:\Users\charl\Documents\CBS\Code Projects_Python\AIML25\AIML25_Project\consolidated.md"
markdown_data = load_markdown_file(file_path)

# %%
import re

def clean_markdown(markdown_data: str) -> str:
    # 1. Remove HTML comments (e.g. <!-- something -->)
    cleaned = re.sub(r'<!--.*?-->', '', markdown_data, flags=re.DOTALL)
    cleaned = re.sub(r"http\S+", "", cleaned)

    # 2. Remove duplicate or irrelevant headers (e.g. "Page Header", "Page Number", etc.)
    irrelevant_headers = [
        r'^#+\s*Page Header\s*$',
        r'^#+\s*Page Number\s*$',
        r'^#+\s*Page Footer\s*$',
        r'^\d{1,2}/\d{1,2}/\d{4},\s*\d{2}:\d{2}\s*$',
        r'^\d+/\d+\s*$'
    ]
    for pattern in irrelevant_headers:
        cleaned = re.sub(pattern, '', cleaned, flags=re.IGNORECASE | re.MULTILINE)

    # 3. Normalize spacing
    cleaned = re.sub(r'\n{2,}', '\n\n', cleaned, flags=re.IGNORECASE)  # Collapse excessive line breaks
    cleaned = re.sub(r'[ \t]+', ' ', cleaned, flags=re.IGNORECASE)     # Remove extra spaces
    cleaned = cleaned.strip()

    return cleaned

# %%
def load_markdown_file(file_path):
    filename = os.path.basename(file_path)  # ✅ get the file name from full path

    with open(file_path, 'r', encoding='utf-8') as f:
        raw_content = f.read()
        cleaned_content = clean_markdown(raw_content)
        product_name = filename.replace(".md", "").replace("_", " ").strip()
        
        markdown_data = [{
            "filename": filename,
            "product_name": product_name,
            "content": cleaned_content
        }]
    
    return markdown_data

# %%
for doc in markdown_data:
    print(f"📄 File: {doc['filename']}")
    print("-" * 60)
    print(doc['content'][:3000])  # Print first 1000 characters (optional)
    print("\n" + "=" * 60 + "\n")
# Out:
# 📄 File: consolidated.md
# ------------------------------------------------------------
# The image displays the logo of Kärcher, a company known for its cleaning equipment. The logo consists of the word "KÄRCHER" in bold, black uppercase letters. Below the text, there is a yellow horizontal bar. The background is white, providing contrast to the black text and yellow bar.
#
# # K 7 POWER FLEX HOME
#
# ## Text
#
# Für mehr Power: K 7 Power Flex Home Hochdruckreiniger mit PremiumFlex-Schlauch, G 180 Q-Pistole für hartnäckige Verschmutzungen rund ums Haus. Inkl. Home Kit.
#
# ## Description
#
# The image displays a Kärcher K7 pressure washer set, which includes several components:
#
# - **Main Unit**: The central piece is the Kärcher K7 pressure washer, characterized by its yellow and black color scheme. It has a sturdy handle for easy maneuverability and large wheels for transport. The model name "K7" is prominently displayed on the side.
#
# - **Accessories**:
#  - **Surface Cleaner**: A circular attachment designed for cleaning flat surfaces. It is also yellow and black, matching the main unit.
#  - **Spray Lances**: Two different spray lances are included, each designed for specific cleaning tasks. They are black and attach to the main unit.
#  - **Detergent Bottle**: A bottle labeled "Stone & Facade" is included, indicating it is a cleaning solution specifically for stone surfaces.
#
# This set is designed for high-performance cleaning, suitable for various outdoor surfaces.
#
# ## Price
#
# 574,99 €
#
# ## Text Content
#
# inkl. MwSt. - kostenlose Lieferung ab 50 €
#
# [
#
# ## K 7 Power Flex Home | Kärcher
#
# This is a page header indicating the product name "K 7 Power Flex Home" by the brand "Kärcher".
#
# Date: 26/04/2025, 18:05
#
# ## K 7 Power Flex Home | Kärcher
#
# This is a page header indicating the product name "K 7 Power Flex Home" by the brand "Kärcher".
#
# ## Text Information
#
# - Lieferbar in: 2-3 Werktagen
# - Bestellnummer: 1.317-302.0
#
# ## Händler Suche
#
# - **Ort oder PLZ**: [Input field]
#
# ### Bewertung
#
# - **Rating**: ★★★★★ 4.7 (48)
# - **Option**: Jetzt Produkt bewerten
#
# ### Funktionen
#
# - **Produkt vergleichen**: [Dropdown or expandable section]
#
# ### Hilfe
#
# - **Benötigen Sie Hilfe?**
#  - **Hotline**: +49 7195 903 0
#
# ## Text
#
# Mit dem Hochdruckreiniger K 7 Power Flex Home lässt sich jede Oberfläche mit passendem Druck reinigen. Um den richtigen Druck zu finden, unterstützt der in der Kärcher Home & Garden App integrierte Anwendungsberater den Nutzer mit praktischen Tipps zu jeder Reinigungssituation und jedem Reinigungsobjekt – für perfekte Reinigungsergebnisse. Der K 7 Power Flex Home ist mit einem wassergekühlten Motor ausgestattet und wurde gebaut für häufige Reinigungseinsätze und starke Verschmutzungen. Das reichhaltige Ausstattungspaket reicht von einer Pistole mit praktischem Quick Connect-Anschluss über einen PremiumFlex-Hochdruckschlauch und einen zuverlässigen Wasserfilter zum Schutz der Pumpe bis zu einem Vario Power-Strahlrohr (VPS) sowie einem Dreckfräser mit rotierendem Punktstrahl. Die Druckeinstellung am VPS lässt sich buchstäblich im Handumdrehen variiere
#
# ============================================================

# %% [markdown]
# ## 3. Parameters

# %%
PARAMS = TextGenParameters(
    temperature=0,              # Higher temperature means more randomness - In this case we don't want randomness
    max_new_tokens= 100,          # Maximum number of tokens to generate
    #min_new_tokens=100, # Minimum number of tokens to generate
    top_k= 10,
    top_p = 0.8,
    stop_sequences= None, # Stop generating text when these sequences are encountered
    )

model = ModelInference(
    api_client=client,
    model_id="ibm/granite-3-8b-instruct",  # We could also try a larger model!
    params=PARAMS
)

# %% [markdown]
# ## 4. System prompt

# %%
SYSTEM_PROMPT = """
You are a multilingual assistant helping to complete missing information about products.

INSTRUCTIONS:
Given the product documentation below, extract the value for the missing field "{field}" for the product "{product_name}".


PRODUCT DOCUMENTATION:
{context}

ANSWER:
"""

# %%
def find_relevant_docs(product_name, product_docs):
    for doc in product_docs:
        print(f"Checking product name: '{product_name}' against '{doc['product_name']}'")
        if product_name.strip().lower() == doc["product_name"].strip().lower():
            return doc["content"]
    return ""

# %%
from rapidfuzz import fuzz

def find_relevant_docs(product_name, product_docs, threshold=85):
    """Finds relevant markdown doc block using fuzzy match."""
    best_match = ""
    best_score = 0

    for doc in product_docs:
        content = doc["content"]
        # Search all lines for best matching line to product_name
        for line in content.splitlines():
            score = fuzz.token_sort_ratio(product_name.lower(), line.strip().lower())
            if score > best_score and score > threshold:
                best_match = content
                best_score = score

    return best_match

# %%
for _, row in df.iterrows():  # This iterates over each row as a Series
    product_name = row["Produktname"]
    md_entry = find_relevant_docs(product_name, markdown_data)

# %%
def query_product_info(product_name, field, markdown_data):
    relevant_doc = find_relevant_docs(product_name, markdown_data)
    if not relevant_doc:
        return "No documentation found mentioning this product."

    context = relevant_doc[:8000]  # Just use the one doc directly
    prompt = SYSTEM_PROMPT.format(
        product_name=product_name,
        context=context,
        field=field
    )

    response = model.generate(prompt)  # Make sure your LLM client returns this format
    answer = response["results"][0]["generated_text"].strip()
    return answer

# %%
product_name = "K 7 Premium Power Flex"
field = "Preis (€ inkl. MwSt.)"
question = f"What is the {field} of the product {product_name}?"

answer = query_product_info(product_name, field, markdown_data)
print("Answer:", answer)
# Out:
# Answer: The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Premium Power Flex" is 574,99 €.

# %%
product_name = "K 5 FJ Home"
field = "Preis (€ inkl. MwSt.)"
question = f"What is the {field} of the product {product_name}?"

answer = query_product_info(product_name, field, markdown_data)
print("Answer:", answer)
# Out:
# Answer: No documentation found mentioning this product.

# %%
# Show the missing fields and query the LLM for each
for idx, product_name, field in missing_fields:
    # Query the LLM to fill the missing value
    print(f"\nFetching answer for missing field '{field}' for product '{product_name}'...")

    answer = query_product_info(product_name, field, markdown_data)
    
    # Show the answer from the LLM without updating the DataFrame
    print(f"Answer for product '{product_name}' ({field}):")
    print(answer)
    print("-" * 60)  # Divider for better readability
# Out:
# Fetching answer for missing field 'Preis (€ inkl. MwSt.)' for product 'K 7 Premium Power Flex'...
# Answer for product 'K 7 Premium Power Flex' (Preis (€ inkl. MwSt.)):
# The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Premium Power Flex" is 574,99 €.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Preis (€ inkl. MwSt.)' for product 'K 5 FJ Home'...
# Answer for product 'K 5 FJ Home' (Preis (€ inkl. MwSt.)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Preis (€ inkl. MwSt.)' for product 'K 5 Premium Power Control Flex Home'...
# Answer for product 'K 5 Premium Power Control Flex Home' (Preis (€ inkl. MwSt.)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Anschlusskabel (m)' for product 'K 4 WCM Premium'...
# Answer for product 'K 4 WCM Premium' (Anschlusskabel (m)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Preis (€ inkl. MwSt.)' for product 'K 4 Classic'...
# Answer for product 'K 4 Classic' (Preis (€ inkl. MwSt.)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Lieferzeit' for product 'K 4 Classic'...
# Answer for product 'K 4 Classic' (Lieferzeit):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Preis (€ inkl. MwSt.)' for product 'K 4 Classic Home'...
# Answer for product 'K 4 Classic Home' (Preis (€ inkl. MwSt.)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Lieferzeit' for product 'K 4 Classic Home'...
# Answer for product 'K 4 Classic Home' (Lieferzeit):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Anschlusskabel (m)' for product 'K 4 WCM Premium Home'...
# Answer for product 'K 4 WCM Premium Home' (Anschlusskabel (m)):
# The missing field "Anschlusskabel (m)" for the product "K 4 WCM Premium Home" is not provided in the given documentation. However, based on the information available for the "K 7 Power Flex Home" product, the "Anschlusskabel (m)" is 5 meters.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Preis (€ inkl. MwSt.)' for product 'K 3 Classic'...
# Answer for product 'K 3 Classic' (Preis (€ inkl. MwSt.)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Lieferzeit' for product 'K 3 Classic'...
# Answer for product 'K 3 Classic' (Lieferzeit):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Preis (€ inkl. MwSt.)' for product 'K 3 Horizontal Plus'...
# Answer for product 'K 3 Horizontal Plus' (Preis (€ inkl. MwSt.)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Lieferzeit' for product 'K 3 Horizontal Plus'...
# Answer for product 'K 3 Horizontal Plus' (Lieferzeit):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Flächenleistung (m²/h)' for product 'K 2 Battery'...
# Answer for product 'K 2 Battery' (Flächenleistung (m²/h)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Anschlussleistung (kW)' for product 'K 2 Battery'...
# Answer for product 'K 2 Battery' (Anschlussleistung (kW)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Anschlussleistung (kW)' for product 'K 2 Premium Horizontal VPS Home'...
# Answer for product 'K 2 Premium Horizontal VPS Home' (Anschlussleistung (kW)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Anschlusskabel (m)' for product 'K 2 Premium Horizontal VPS Home'...
# Answer for product 'K 2 Premium Horizontal VPS Home' (Anschlusskabel (m)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Preis (€ inkl. MwSt.)' for product 'K 2 Battery Set'...
# Answer for product 'K 2 Battery Set' (Preis (€ inkl. MwSt.)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Lieferzeit' for product 'K 2 Battery Set'...
# Answer for product 'K 2 Battery Set' (Lieferzeit):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Flächenleistung (m²/h)' for product 'K 2 Battery Set'...
# Answer for product 'K 2 Battery Set' (Flächenleistung (m²/h)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Anschlussleistung (kW)' for product 'K 2 Battery Set'...
# Answer for product 'K 2 Battery Set' (Anschlussleistung (kW)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Anschlusskabel (m)' for product 'K 2 Universal Edition'...
# Answer for product 'K 2 Universal Edition' (Anschlusskabel (m)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Anschlusskabel (m)' for product 'K 2 Universal Edition Home'...
# Answer for product 'K 2 Universal Edition Home' (Anschlusskabel (m)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Preis (€ inkl. MwSt.)' for product 'K Mini'...
# Answer for product 'K Mini' (Preis (€ inkl. MwSt.)):
# No documentation found mentioning this product.
# ------------------------------------------------------------
#
# Fetching answer for missing field 'Lieferzeit' for product 'K Mini'...
# Answer for product 'K Mini' (Lieferzeit):
# No documentation found mentioning this product.
# ------------------------------------------------------------

# %%
completed_data = []

for _, row in df.iterrows():
    product_name = row["Produktname"]
    context = find_relevant_docs(product_name, markdown_data)
    
    for field in df.columns:
        value = row[field]
        if pd.isna(value) or value in ["", "N/A", "–"]:
            prompt = SYSTEM_PROMPT.format(field=field, context=context)
            response = model.generate(prompt)
            answer = response["results"][0]["generated_text"].strip()

            completed_data.append({
                "product": product_name,
                "field": field,
                "predicted_value": answer
            })

# %%
fields_to_check = [
    "Preis (€ inkl. MwSt.)",
    "Lieferzeit",
    "Stromart (V/Hz)",
    "Druck (bar/MPa)",
    "Fördermenge (l/h)",
    "Flächenleistung (m²/h)", 
    "Zulauftemperatur (°C)",
    "Anschlussleistung (kW)",
    "Anschlusskabel (m)",
    "Farbe",
    "Gewicht ohne Zubehör (kg)",
    "Gewicht inkl. Verpackung (kg)",
    "Abmessungen (L × B × H) (mm)",
    "Lieferumfang",
    "Ausstattung",
]

# %%
results = []

for _, row in df.iterrows():
    product = row["Produktname"]

    for field in fields_to_check:
        question = f"What is the {field} of {product}?"
        llm_answer = query_product_info(product, field, markdown_data)
        ground_truth = str(row[field])

        # Optional: Normalize answers
        is_correct = llm_answer.strip().lower() == ground_truth.strip().lower()

        results.append({
            "product": product,
            "field": field,
            "llm_answer": llm_answer,
            "ground_truth": ground_truth,
            "correct": is_correct
        })

# %%
results
# Out:
# [{'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Premium Smart Control Flex eco!B" is not provided in the given documentation. However, based on the similar product "K 7 Power Flex Home" which is priced at 574,99 €, it can be inferred that the price for "K 7 Premium Smart Control Flex eco!B" might be around 574,9',
#   'ground_truth': '664.99',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Lieferzeit',
#   'llm_answer': 'The missing field "Lieferzeit" for the product "K 7 Premium Smart Control Flex eco!B" is not explicitly mentioned in the provided documentation. However, based on the information available for the "K 7 Power Flex Home" product, which is similar, the delivery time is indicated as "2-3 Werktagen" (2-3 working days). Therefore, it can be inferred that the delivery time for "K 7 Premium Smart Control Flex eco!',
#   'ground_truth': '2-3 Werktage',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'The missing field "Stromart (V/Hz)" for the product "K 7 Premium Smart Control Flex eco!B" is 230 / 50.',
#   'ground_truth': '230 / 50',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'The missing field "Druck (bar/MPa)" for the product "K 7 Premium Smart Control Flex eco!B" is 20 - max. 180 / 2 - max. 18.',
#   'ground_truth': '20 - max. 180 / 2 - max. 18',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'The missing field "Fördermenge (l/h)" for the product "K 7 Premium Smart Control Flex eco!B" is not explicitly provided in the given documentation. However, based on the similar product "K 7 Power Flex Home," the maximum flow rate (Fördermenge) is listed as max. 600 l/h. Therefore, it is reasonable to assume that the "K 7 Premium Smart Control Flex eco!B" also',
#   'ground_truth': 'max. 600',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'The missing field "Flächenleistung (m²/h)" for the product "K 7 Premium Smart Control Flex eco!B" is 60.',
#   'ground_truth': '60',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'The missing field "Zulauftemperatur (°C)" for the product "K 7 Premium Smart Control Flex eco!B" is not explicitly provided in the given documentation. However, based on the similar product "K 7 Power Flex Home," the maximum inlet temperature is 60°C. Therefore, it can be inferred that the "K 7 Premium Smart Control Flex eco!B" also has a maximum inlet temperature of 60°C.',
#   'ground_truth': 'max. 60',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'The missing field "Anschlussleistung (kW)" for the product "K 7 Premium Smart Control Flex eco!B" is 3 kW.',
#   'ground_truth': '3',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'The missing field "Anschlusskabel (m)" for the product "K 7 Premium Smart Control Flex eco!B" is 5 meters.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Farbe',
#   'llm_answer': 'The missing field "Farbe" (color) for the product "K 7 Premium Smart Control Flex eco!B" is not explicitly mentioned in the provided documentation. However, based on the description of the K 7 Power Flex Home, which is a similar model, the color is indicated as "gelb" (yellow). Therefore, it can be inferred that the color for the "K 7 Premium Smart Control Flex eco!B" is likely "gelb" (yellow).',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': '17.3',
#   'ground_truth': '17.8',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'The missing field "Gewicht inkl. Verpackung (kg)" for the product "K 7 Premium Smart Control Flex eco!B" is 24.9 kg.',
#   'ground_truth': '24.4',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'The missing field "Abmessungen (L × B × H) (mm)" for the product "K 7 Premium Smart Control Flex eco!B" is 458 × 330 × 666.',
#   'ground_truth': '459 x 330 x 669',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Lieferumfang',
#   'llm_answer': 'The missing field "Lieferumfang" for the product "K 7 Premium Smart Control Flex eco!B" is not explicitly mentioned in the provided documentation. However, based on the information available for the "K 7 Power Flex Home" product, the delivery contents for the "K 7 Premium Smart Control Flex eco!B" are likely to include:\n\n- Home Kit: Flächenreiniger T 7, Stein- und Fassadenre',
#   'ground_truth': 'G 180 Q Smart Control, Multi Jet 3-in-1, eco!Booster, HD-Schlauch 10 m PremiumFlex, Adapter Gartenschlauchanschluss A3/4',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex eco!B',
#   'field': 'Ausstattung',
#   'llm_answer': 'The missing field "Ausstattung" (Equipment) for the product "K 7 Premium Smart Control Flex eco!B" is not explicitly mentioned in the provided documentation. However, based on the similar product "K 7 Power Flex Home," we can infer that the "K 7 Premium Smart Control Flex eco!B" would likely have a similar or enhanced set of features.\n\nFrom the "K 7 Power Flex Home" documentation, the "Ausst',
#   'ground_truth': 'Teleskopgriff, Integrierter Wasserfilter',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Premium Smart Control Flex Home" is 574.99 €.',
#   'ground_truth': '694.99',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Lieferzeit',
#   'llm_answer': 'The missing field "Lieferzeit" for the product "K 7 Premium Smart Control Flex Home" is "2-3 Werktagen".',
#   'ground_truth': '2-3 Werktage',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'The missing field "Stromart (V/Hz)" for the product "K 7 Premium Smart Control Flex Home" is 230 / 50.',
#   'ground_truth': '230 / 50',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'The missing field "Druck (bar/MPa)" for the product "K 7 Premium Smart Control Flex Home" is 20 - max. 180 / 2 - max. 18.',
#   'ground_truth': '20 - max. 180 / 2 - max. 18',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'The missing field "Fördermenge (l/h)" for the product "K 7 Premium Smart Control Flex Home" is max. 600.',
#   'ground_truth': 'max. 600',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'The missing field "Flächenleistung (m²/h)" for the product "K 7 Premium Smart Control Flex Home" is 60.',
#   'ground_truth': '60',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'The missing field "Zulauftemperatur (°C)" for the product "K 7 Premium Smart Control Flex Home" is 60.',
#   'ground_truth': 'max. 60',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'The missing field "Anschlussleistung (kW)" for the product "K 7 Premium Smart Control Flex Home" is 3 kW.',
#   'ground_truth': '3',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'The missing field "Anschlusskabel (m)" for the product "K 7 Premium Smart Control Flex Home" is 5 meters.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Farbe',
#   'llm_answer': 'The missing field "Farbe" (color) for the product "K 7 Premium Smart Control Flex Home" is "gelb" (yellow).',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': '17.3',
#   'ground_truth': '17.8',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'The missing field "Gewicht inkl. Verpackung (kg)" for the product "K 7 Premium Smart Control Flex Home" is 24.9 kg.',
#   'ground_truth': '25.6',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'The missing field "Abmessungen (L × B × H) (mm)" for the product "K 7 Premium Smart Control Flex Home" is 458 × 330 × 666.',
#   'ground_truth': '459 x 330 x 669',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Lieferumfang',
#   'llm_answer': 'The missing field "Lieferumfang" for the product "K 7 Premium Smart Control Flex Home" is:\n\n- Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger, 3in1, 1 l\n- Hochdruckpistole: G 180 Q\n- Dreckfräser\n- HD-Schlauch: 10 m, Premium',
#   'ground_truth': 'Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger 1l, G 180 Q Smart Control, Multi Jet 3-in-1, HD-Schlauch 10 m PremiumFlex, Adapter Gartenschlauchanschluss A3/4',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex Home',
#   'field': 'Ausstattung',
#   'llm_answer': 'The missing field "Ausstattung" (Equipment/Features) for the product "K 7 Premium Smart Control Flex Home" includes:\n\n- Vario Power Jet\n- Integriertes Aufbewahrungsnetz\n- Geräteseitiges Quick Connect\n- Reinigungsmittel-einsatz über: Plug \'n\' Clean-System\n- Teleskopgriff\n- Wassergekühlter',
#   'ground_truth': "Integrierte HD-Schlauchtrommel, Integriertes Aufbewahrungsnetz, Quick Connect, Plug 'n' Clean-System, Teleskopgriff, Wassergekühlter Motor, Integrierter Wasserfilter, Bluetooth-App-Verbindung",
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Premium Power Flex" is 574,99 €.',
#   'ground_truth': ' ',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Lieferzeit',
#   'llm_answer': 'The missing field "Lieferzeit" for the product "K 7 Premium Power Flex" is "2-3 Werktagen".',
#   'ground_truth': '2-3 Werktage',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'The missing field "Stromart (V/Hz)" for the product "K 7 Premium Power Flex" is 230 / 50.',
#   'ground_truth': '230 / 50',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'The missing field "Druck (bar/MPa)" for the product "K 7 Premium Power Flex" is 20 - max. 180 / 2 - max. 18.',
#   'ground_truth': '20 - max. 180 / 2 - max. 18',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'The missing field "Fördermenge (l/h)" for the product "K 7 Premium Power Flex" is max. 600.',
#   'ground_truth': 'max. 600',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'The missing field "Flächenleistung (m²/h)" for the product "K 7 Premium Power Flex" is 60.',
#   'ground_truth': '60',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'The missing field "Zulauftemperatur (°C)" for the product "K 7 Premium Power Flex" is 60.',
#   'ground_truth': 'max. 60',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'The missing field "Anschlussleistung (kW)" for the product "K 7 Premium Power Flex" is 3 kW.',
#   'ground_truth': '3',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'The missing field "Anschlusskabel (m)" for the product "K 7 Premium Power Flex" is 5.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Farbe',
#   'llm_answer': 'The missing field "Farbe" (color) for the product "K 7 Premium Power Flex" is "gelb" (yellow).',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': '17.3',
#   'ground_truth': '17.8',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'The missing field "Gewicht inkl. Verpackung (kg)" for the product "K 7 Premium Power Flex" is 24.9 kg.',
#   'ground_truth': '22.2',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'The missing field "Abmessungen (L × B × H) (mm)" for the product "K 7 Premium Power Flex" is 458 × 330 × 666.',
#   'ground_truth': '459 x 330 x 669',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Lieferumfang',
#   'llm_answer': 'The missing field "Lieferumfang" for the product "K 7 Premium Power Flex" includes:\n\n- Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger, 3in1, 1 l\n- Hochdruckpistole: G 180 Q\n- Dreckfräser\n- HD-Schlauch: 10 m, PremiumFlex',
#   'ground_truth': 'G 180 Q, Dreckfräser, HD-Schlauch 10 m PremiumFlex, Adapter Gartenschlauchanschluss A3/4',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex',
#   'field': 'Ausstattung',
#   'llm_answer': 'The missing field "Ausstattung" (Equipment) for the product "K 7 Premium Power Flex" includes:\n\n- Vario Power Jet\n- Integriertes Aufbewahrungsnetz\n- Geräteseitiges Quick Connect\n- Reinigungsmittel-einsatz über: Plug \'n\' Clean-System\n- Teleskopgriff\n- Wassergekühlter Motor\n- In',
#   'ground_truth': "Vario Power Jet, Integrierte HD-Schlauchtrommel, Integriertes Aufbewahrungsnetz, Quick Connect, Plug 'n' Clean-System, Teleskopgriff, Wassergekühlter Motor, Integrierter Wasserfilter",
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Premium Power Flex Home" is 574,99 €.',
#   'ground_truth': '624.99',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Lieferzeit',
#   'llm_answer': 'The missing field "Lieferzeit" for the product "K 7 Premium Power Flex Home" is "2-3 Werktagen".',
#   'ground_truth': '2-3 Werktage',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'The missing field "Stromart (V/Hz)" for the product "K 7 Premium Power Flex Home" is 230 / 50.',
#   'ground_truth': '230 / 50',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'The missing field "Druck (bar/MPa)" for the product "K 7 Premium Power Flex Home" is 20 - max. 180 / 2 - max. 18.',
#   'ground_truth': '20 - max. 180 / 2 - max. 18',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'The missing field "Fördermenge (l/h)" for the product "K 7 Premium Power Flex Home" is max. 600.',
#   'ground_truth': 'max. 600',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'The missing field "Flächenleistung (m²/h)" for the product "K 7 Premium Power Flex Home" is 60.',
#   'ground_truth': '60',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'The missing field "Zulauftemperatur (°C)" for the product "K 7 Premium Power Flex Home" is 60.',
#   'ground_truth': 'max. 60',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'The missing field "Anschlussleistung (kW)" for the product "K 7 Premium Power Flex Home" is 3 kW.',
#   'ground_truth': '3',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'The missing field "Anschlusskabel (m)" for the product "K 7 Premium Power Flex Home" is 5 meters.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Farbe',
#   'llm_answer': 'The missing field "Farbe" (color) for the product "K 7 Premium Power Flex Home" is "gelb" (yellow).',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': '17.3 kg',
#   'ground_truth': '17.8',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'The missing field "Gewicht inkl. Verpackung (kg)" for the product "K 7 Premium Power Flex Home" is 24.9 kg.',
#   'ground_truth': '25.4',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'The missing field "Abmessungen (L × B × H) (mm)" for the product "K 7 Premium Power Flex Home" is 458 × 330 × 666.',
#   'ground_truth': '459 x 330 x 669',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Lieferumfang',
#   'llm_answer': 'The missing field "Lieferumfang" for the product "K 7 Premium Power Flex Home" is:\n\n- Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger, 3in1, 1 l\n- Hochdruckpistole: G 180 Q\n- Dreckfräser\n- HD-Schlauch: 10 m, PremiumFlex',
#   'ground_truth': 'Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger 1l, G 180 Q, Dreckfräser, HD-Schlauch 10 m PremiumFlex, Adapter Gartenschlauchanschluss A3/4',
#   'correct': False},
#  {'product': 'K 7 Premium Power Flex Home',
#   'field': 'Ausstattung',
#   'llm_answer': 'The missing field "Ausstattung" (Equipment/Features) for the product "K 7 Premium Power Flex Home" includes:\n\n- Vario Power Jet\n- Integriertes Aufbewahrungsnetz\n- Geräteseitiges Quick Connect\n- Reinigungsmittel-einsatz über: Plug \'n\' Clean-System\n- Teleskopgriff\n- Wassergekühlter Motor',
#   'ground_truth': "Vario Power Jet, Integrierte HD-Schlauchtrommel, Integriertes Aufbewahrungsnetz, Quick Connect, Plug 'n' Clean-System, Teleskopgriff, Wassergekühlter Motor, Integrierter Wasserfilter",
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Premium Smart Control Flex" is not explicitly provided in the given documentation. However, based on the information available for the "K 7 Power Flex Home" model, which is similar, the price is 574,99 €. Therefore, it can be inferred that the price for the "K 7 Premium Smart Control Flex" is likely to be around',
#   'ground_truth': '624.99',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Lieferzeit',
#   'llm_answer': 'The missing field "Lieferzeit" for the product "K 7 Premium Smart Control Flex" is not explicitly mentioned in the provided documentation. However, based on the information available for the "K 7 Power Flex Home" product, which is similar, the delivery time is listed as "2-3 Werktagen" or "2-3 working days". Therefore, it can be inferred that the delivery time for the "K 7 Premium Smart Control Flex" is likely',
#   'ground_truth': '2-3 Werktage',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'The missing field "Stromart (V/Hz)" for the product "K 7 Premium Smart Control Flex" is 230 / 50.',
#   'ground_truth': '230 / 50',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'The missing field "Druck (bar/MPa)" for the product "K 7 Premium Smart Control Flex" is 20 - max. 180 / 2 - max. 18.',
#   'ground_truth': '20 - max. 180 / 2 - max. 18',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'The missing field "Fördermenge (l/h)" for the product "K 7 Premium Smart Control Flex" is max. 600.',
#   'ground_truth': 'max. 600',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'The missing field "Flächenleistung (m²/h)" for the product "K 7 Premium Smart Control Flex" is 60.',
#   'ground_truth': '60',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'The missing field "Zulauftemperatur (°C)" for the product "K 7 Premium Smart Control Flex" is 60.',
#   'ground_truth': 'max. 60',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'The missing field "Anschlussleistung (kW)" for the product "K 7 Premium Smart Control Flex" is 3 kW.',
#   'ground_truth': '3',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'The missing field "Anschlusskabel (m)" for the product "K 7 Premium Smart Control Flex" is 5 meters.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Farbe',
#   'llm_answer': 'The missing field "Farbe" (color) for the product "K 7 Premium Smart Control Flex" is yellow.',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': '17.3',
#   'ground_truth': '17.8',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'The missing field "Gewicht inkl. Verpackung (kg)" for the product "K 7 Premium Smart Control Flex" is 24.9 kg.',
#   'ground_truth': '23.0',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'The missing field "Abmessungen (L × B × H) (mm)" for the product "K 7 Premium Smart Control Flex" is 458 × 330 × 666.',
#   'ground_truth': '459 x 330 x 669',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Lieferumfang',
#   'llm_answer': 'The missing field "Lieferumfang" for the product "K 7 Premium Smart Control Flex" is:\n\n- Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger, 3in1, 1 l\n- Hochdruckpistole: G 180 Q\n- Dreckfräser\n- HD-Schlauch: 10 m, PremiumFlex',
#   'ground_truth': 'G 180 Q Smart Control, Multi Jet 3-in-1, HD-Schlauch 10 m PremiumFlex, Adapter Gartenschlauchanschluss A3/4',
#   'correct': False},
#  {'product': 'K 7 Premium Smart Control Flex',
#   'field': 'Ausstattung',
#   'llm_answer': 'The missing field "Ausstattung" (Equipment/Features) for the product "K 7 Premium Smart Control Flex" is:\n\n- Vario Power Jet\n- Integriertes Aufbewahrungsnetz\n- Geräteseitiges Quick Connect\n- Reinigungsmittel-einsatz über: Plug \'n\' Clean-System\n- Teleskopgriff\n- Wassergekühlter Motor',
#   'ground_truth': "Integrierte HD-Schlauchtrommel, Integriertes Aufbewahrungsnetz, Quick Connect, Plug 'n' Clean-System, Teleskopgriff, Wassergekühlter Motor, Integrierter Wasserfilter",
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Smart Control Flex eco!Booster" is not provided in the given documentation. However, based on the information available for the "K 7 Power Flex Home" model, the price is 574,99 €. Please note that this is an approximation, as the exact product "K 7 Smart Control Flex eco!Booster" is not mentioned',
#   'ground_truth': '614.99',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Lieferzeit',
#   'llm_answer': 'The missing field "Lieferzeit" for the product "K 7 Smart Control Flex eco!Booster" is not explicitly mentioned in the provided documentation. However, based on the information available for the "K 7 Power Flex Home" product, which is similar, the delivery time is listed as "2-3 Werktagen" (2-3 working days). Therefore, it can be inferred that the delivery time for the "K 7 Smart Control Flex eco!',
#   'ground_truth': '2-3 Werktage',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'The missing field "Stromart (V/Hz)" for the product "K 7 Smart Control Flex eco!Booster" is 230 / 50.',
#   'ground_truth': '230 / 50',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'The missing field "Druck (bar/MPa)" for the product "K 7 Smart Control Flex eco!Booster" is 20 - max. 180 / 2 - max. 18.',
#   'ground_truth': '20 - max. 180 / 2 - max. 18',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'The missing field "Fördermenge (l/h)" for the product "K 7 Smart Control Flex eco!Booster" is not explicitly provided in the given documentation. However, based on the similar product "K 7 Power Flex Home," the maximum flow rate (Fördermenge) is listed as max. 600 l/h.\n\nTherefore, the estimated value for "Fördermenge (l/h)" for the',
#   'ground_truth': 'max. 600',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'The missing field "Flächenleistung (m²/h)" for the product "K 7 Smart Control Flex eco!Booster" is 60.',
#   'ground_truth': '60',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'The missing field "Zulauftemperatur (°C)" for the product "K 7 Smart Control Flex eco!Booster" is not explicitly provided in the given documentation. However, based on the information available for the "K 7 Power Flex Home" model, the maximum inlet temperature is 60°C.\n\nTherefore, the value for "Zulauftemperatur (°C)" for the "K 7 Smart Control Flex eco!',
#   'ground_truth': 'max. 60',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'The missing field "Anschlussleistung (kW)" for the product "K 7 Smart Control Flex eco!Booster" is 3 kW.',
#   'ground_truth': '3',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'The missing field "Anschlusskabel (m)" for the product "K 7 Smart Control Flex eco!Booster" is 5 meters.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Farbe',
#   'llm_answer': 'The missing field "Farbe" (color) for the product "K 7 Smart Control Flex eco!Booster" is not explicitly mentioned in the provided documentation. However, based on the context and the color scheme of the K 7 Power Flex Home, which is a similar model, the color can be inferred as "gelb" (yellow).',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': '17.3',
#   'ground_truth': '17.3',
#   'correct': True},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'The missing field "Gewicht inkl. Verpackung (kg)" for the product "K 7 Smart Control Flex eco!Booster" is 24.9 kg.',
#   'ground_truth': '24.0',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'The missing field "Abmessungen (L × B × H) (mm)" for the product "K 7 Smart Control Flex eco!Booster" is 458 × 330 × 666.',
#   'ground_truth': '458 x 330 x 669',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Lieferumfang',
#   'llm_answer': 'The missing field "Lieferumfang" for the product "K 7 Smart Control Flex eco!Booster" is not explicitly mentioned in the provided documentation. However, based on the information available for the "K 7 Power Flex Home" product, the "Lieferumfang" (delivery contents) includes:\n\n- Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger, 3in1,',
#   'ground_truth': 'G 180 Q Smart Control, Multi Jet 3-in-1, eco!Booster, 1 l Universalreiniger, HD-Schlauch 10 m PremiumFlex, Adapter Gartenschlauchanschluss A3/4',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex eco!Booster',
#   'field': 'Ausstattung',
#   'llm_answer': 'The missing field "Ausstattung" (Equipment) for the product "K 7 Smart Control Flex eco!Booster" is not explicitly mentioned in the provided documentation. However, based on the information available for the "K 7 Power Flex Home" model, which is similar, the equipment can be inferred as follows:\n\n- **Vario Power Jet**\n- **Integriertes Aufbewahrungsnetz** (Integrated Storage Net',
#   'ground_truth': "Integrierte HD-Schlauchtrommel, Integriertes Aufbewahrungsnetz, Quick Connect, Plug 'n' Clean-System, Teleskopgriff, Wassergekühlter Motor, Integrierter Wasserfilter",
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Smart Control Flex Home" is 574,99 €.',
#   'ground_truth': '644.99',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Lieferzeit',
#   'llm_answer': 'The missing field "Lieferzeit" for the product "K 7 Smart Control Flex Home" is "2-3 Werktagen".',
#   'ground_truth': '2-3 Werktage',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'The missing field "Stromart (V/Hz)" for the product "K 7 Smart Control Flex Home" is 230 / 50.',
#   'ground_truth': '230 / 50',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'The missing field "Druck (bar/MPa)" for the product "K 7 Smart Control Flex Home" is 20 - max. 180 / 2 - max. 18.',
#   'ground_truth': '20 - max. 180 / 2 - max. 18',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'The missing field "Fördermenge (l/h)" for the product "K 7 Smart Control Flex Home" is max. 600.',
#   'ground_truth': 'max. 600',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'The missing field "Flächenleistung (m²/h)" for the product "K 7 Smart Control Flex Home" is 60.',
#   'ground_truth': '60',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'The missing field "Zulauftemperatur (°C)" for the product "K 7 Smart Control Flex Home" is 60.',
#   'ground_truth': 'max. 60',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'The missing field "Anschlussleistung (kW)" for the product "K 7 Smart Control Flex Home" is 3 kW.',
#   'ground_truth': '3',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'The missing field "Anschlusskabel (m)" for the product "K 7 Smart Control Flex Home" is 5 meters.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Farbe',
#   'llm_answer': 'The missing field "Farbe" (color) for the product "K 7 Smart Control Flex Home" is "gelb" (yellow).',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': '17.3',
#   'ground_truth': '17.3',
#   'correct': True},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'The missing field "Gewicht inkl. Verpackung (kg)" for the product "K 7 Smart Control Flex Home" is 24.9 kg.',
#   'ground_truth': '25.2',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'The missing field "Abmessungen (L × B × H) (mm)" for the product "K 7 Smart Control Flex Home" is 458 × 330 × 666.',
#   'ground_truth': '458 x 330 x 669',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Lieferumfang',
#   'llm_answer': 'The missing field "Lieferumfang" for the product "K 7 Smart Control Flex Home" is:\n\n- Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger, 3in1, 1 l\n- Hochdruckpistole: G 180 Q\n- Dreckfräser\n- HD-Schlauch: 10 m, PremiumFlex',
#   'ground_truth': 'Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger 1l, G 180 Q Smart Control, Multi Jet 3-in-1, HD-Schlauch 10 m PremiumFlex, Adapter Gartenschlauchanschluss A3/4',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex Home',
#   'field': 'Ausstattung',
#   'llm_answer': 'The missing field "Ausstattung" (Equipment/Features) for the product "K 7 Smart Control Flex Home" is:\n\n- Vario Power Jet\n- Integriertes Aufbewahrungsnetz\n- Geräteseitiges Quick Connect\n- Reinigungsmittel-einsatz über: Plug \'n\' Clean-System\n- Teleskopgriff\n- Wassergekühlter Motor',
#   'ground_truth': "Integriertes Aufbewahrungsnetz, Quick Connect, Plug 'n' Clean-System, Wassergekühlter Motor, Integrierter Wasserfilter, Bluetooth-App-Verbindung",
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Power Flex" is 574,99 €.',
#   'ground_truth': '504.99',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Lieferzeit',
#   'llm_answer': 'The missing field "Lieferzeit" for the product "K 7 Power Flex" is "2-3 Werktagen".',
#   'ground_truth': '2-3 Werktage',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'The missing field "Stromart (V/Hz)" for the product "K 7 Power Flex" is 230 / 50.',
#   'ground_truth': '230 / 50',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'The missing field "Druck (bar/MPa)" for the product "K 7 Power Flex" is 20 - max. 180 / 2 - max. 18.',
#   'ground_truth': '20 - max. 180 / 2 - max. 18',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'The missing field "Fördermenge (l/h)" for the product "K 7 Power Flex" is max. 600.',
#   'ground_truth': 'max. 600',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'The missing field "Flächenleistung (m²/h)" for the product "K 7 Power Flex" is 60.',
#   'ground_truth': '60',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'The missing field "Zulauftemperatur (°C)" for the product "K 7 Power Flex" is 60.',
#   'ground_truth': 'max. 60',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'The missing field "Anschlussleistung (kW)" for the product "K 7 Power Flex" is 3.',
#   'ground_truth': '3',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'The missing field "Anschlusskabel (m)" for the product "K 7 Power Flex" is 5.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Farbe',
#   'llm_answer': 'The missing field "Farbe" (color) for the product "K 7 Power Flex" is "gelb" (yellow).',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': '17.3 kg',
#   'ground_truth': '17.3',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'The missing field "Gewicht inkl. Verpackung (kg)" for the product "K 7 Power Flex" is 24.9 kg.',
#   'ground_truth': '23.0',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'The missing field "Abmessungen (L × B × H) (mm)" for the product "K 7 Power Flex" is 458 × 330 × 666.',
#   'ground_truth': '458 x 330 x 669',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Lieferumfang',
#   'llm_answer': 'The missing field "Lieferumfang" for the product "K 7 Power Flex" includes:\n\n- Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger, 3in1, 1 l\n- Hochdruckpistole: G 180 Q\n- Dreckfräser\n- HD-Schlauch: 10 m, PremiumFlex\n-',
#   'ground_truth': 'G 180 Q, Dreckfräser, HD-Schlauch 10 m PremiumFlex, Adapter Gartenschlauchanschluss A3/4',
#   'correct': False},
#  {'product': 'K 7 Power Flex',
#   'field': 'Ausstattung',
#   'llm_answer': 'The missing field "Ausstattung" (Equipment) for the product "K 7 Power Flex Home" includes:\n\n- Vario Power Jet\n- Integriertes Aufbewahrungsnetz\n- Geräteseitiges Quick Connect\n- Reinigungsmittel-einsatz über: Plug \'n\' Clean-System\n- Teleskopgriff\n- Wassergekühlter Motor\n- In',
#   'ground_truth': "Vario Power Jet, Integriertes Aufbewahrungsnetz, Quick Connect, Plug 'n' Clean-System, Teleskopgriff, Wassergekühlter Motor, Integrierter Wasserfilter",
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Power Flex Home" is 574,99 €.',
#   'ground_truth': '574.99',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Lieferzeit',
#   'llm_answer': 'The missing field "Lieferzeit" for the product "K 7 Power Flex Home" is "2-3 Werktagen".',
#   'ground_truth': '2-3 Werktage',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'The missing field "Stromart (V/Hz)" for the product "K 7 Power Flex Home" is 230 / 50.',
#   'ground_truth': '230 / 50',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'The missing field "Druck (bar/MPa)" for the product "K 7 Power Flex Home" is 20 - max. 180 / 2 - max. 18.',
#   'ground_truth': '20 - max. 180 / 2 - max. 18',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'The missing field "Fördermenge (l/h)" for the product "K 7 Power Flex Home" is max. 600.',
#   'ground_truth': 'max. 600',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'The missing field "Flächenleistung (m²/h)" for the product "K 7 Power Flex Home" is 60.',
#   'ground_truth': '60',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'The missing field "Zulauftemperatur (°C)" for the product "K 7 Power Flex Home" is 60.',
#   'ground_truth': 'max. 60',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'The missing field "Anschlussleistung (kW)" for the product "K 7 Power Flex Home" is 3 kW.',
#   'ground_truth': '3',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'The missing field "Anschlusskabel (m)" for the product "K 7 Power Flex Home" is 5.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Farbe',
#   'llm_answer': 'The missing field "Farbe" (color) for the product "K 7 Power Flex Home" is "gelb" (yellow).',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': '17.3 kg',
#   'ground_truth': '17.3',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'The missing field "Gewicht inkl. Verpackung (kg)" for the product "K 7 Power Flex Home" is 24.9 kg.',
#   'ground_truth': '24.9',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'The missing field "Abmessungen (L × B × H) (mm)" for the product "K 7 Power Flex Home" is 458 × 330 × 666.',
#   'ground_truth': '458 x 330 x 669',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Lieferumfang',
#   'llm_answer': 'The missing field "Lieferumfang" for the product "K 7 Power Flex Home" is:\n\n- Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger, 3in1, 1 l\n- Hochdruckpistole: G 180 Q\n- Dreckfräser\n- HD-Schlauch: 10 m, PremiumFlex',
#   'ground_truth': 'Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger 1l, G 180 Q, Dreckfräser, HD-Schlauch 10 m PremiumFlex, Adapter Gartenschlauchanschluss A3/4',
#   'correct': False},
#  {'product': 'K 7 Power Flex Home',
#   'field': 'Ausstattung',
#   'llm_answer': 'The missing field "Ausstattung" (Equipment) for the product "K 7 Power Flex Home" includes:\n\n- Vario Power Jet\n- Integriertes Aufbewahrungsnetz\n- Geräteseitiges Quick Connect\n- Reinigungsmittel-einsatz über: Plug \'n\' Clean-System\n- Teleskopgriff\n- Wassergekühlter Motor\n- In',
#   'ground_truth': "Vario Power Jet, Integriertes Aufbewahrungsnetz, Quick Connect, Plug 'n' Clean-System, Teleskopgriff, Wassergekühlter Motor, Integrierter Wasserfilter",
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 Smart Control Flex" is not provided in the given documentation. However, based on the information available for the "K 7 Power Flex Home" which is a similar product, the price is 574,99 €.\n\nPlease note that the "K 7 Smart Control Flex" is not explicitly mentioned in the provided documentation, and the price for',
#   'ground_truth': '574.99',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Lieferzeit',
#   'llm_answer': 'The missing field "Lieferzeit" for the product "K 7 Smart Control Flex" is not explicitly mentioned in the provided documentation. However, based on the information available for the "K 7 Power Flex Home" product, which is similar, the delivery time is listed as "2-3 Werktagen" or "2-3 working days". Therefore, it can be inferred that the delivery time for "K 7 Smart Control Flex" is likely to be the',
#   'ground_truth': '2-3 Werktage',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'The missing field "Stromart (V/Hz)" for the product "K 7 Smart Control Flex" is 230 / 50.',
#   'ground_truth': '230 / 50',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'The missing field "Druck (bar/MPa)" for the product "K 7 Smart Control Flex" is 20 - max. 180 / 2 - max. 18.',
#   'ground_truth': '20 - max. 180 / 2 - max. 18',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'The missing field "Fördermenge (l/h)" for the product "K 7 Smart Control Flex" is max. 600.',
#   'ground_truth': 'max. 600',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'The missing field "Flächenleistung (m²/h)" for the product "K 7 Smart Control Flex" is 60.',
#   'ground_truth': '60',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'The missing field "Zulauftemperatur (°C)" for the product "K 7 Smart Control Flex" is not explicitly mentioned in the provided documentation. However, based on the information available for the "K 7 Power Flex Home" model, the maximum inlet temperature is 60°C.\n\nTherefore, the value for "Zulauftemperatur (°C)" for the "K 7 Smart Control Flex" is likely 60',
#   'ground_truth': 'max. 60',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'The missing field "Anschlussleistung (kW)" for the product "K 7 Smart Control Flex" is 3 kW.',
#   'ground_truth': '3',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'The missing field "Anschlusskabel (m)" for the product "K 7 Smart Control Flex" is 5 meters.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Farbe',
#   'llm_answer': 'The missing field "Farbe" (color) for the product "K 7 Smart Control Flex" is yellow.',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': '17.3',
#   'ground_truth': '17.3',
#   'correct': True},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'The missing field "Gewicht inkl. Verpackung (kg)" for the product "K 7 Smart Control Flex" is 24.9 kg.',
#   'ground_truth': '22.6',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'The missing field "Abmessungen (L × B × H) (mm)" for the product "K 7 Smart Control Flex" is 458 × 330 × 666.',
#   'ground_truth': '458 x 330 x 669',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Lieferumfang',
#   'llm_answer': 'The missing field "Lieferumfang" for the product "K 7 Smart Control Flex" is:\n\n- Home Kit: Flächenreiniger T 7, Stein- und Fassadenreiniger, 3in1, 1 l\n- Hochdruckpistole: G 180 Q\n- Dreckfräser\n- HD-Schlauch: 10 m, PremiumFlex',
#   'ground_truth': 'G 180 Q Smart Control, Multi Jet 3-in-1, HD-Schlauch 10 m PremiumFlex, Adapter Gartenschlauchanschluss A3/4',
#   'correct': False},
#  {'product': 'K 7 Smart Control Flex',
#   'field': 'Ausstattung',
#   'llm_answer': 'The missing field "Ausstattung" (Equipment) for the product "K 7 Smart Control Flex" is not explicitly mentioned in the provided documentation. However, based on the description of the "K 7 Power Flex Home" which is a similar model, the equipment includes:\n\n- Vario Power Jet\n- Integriertes Aufbewahrungsnetz (Integrated Storage Net)\n- Geräteseitiges Quick Connect (',
#   'ground_truth': "Integriertes Aufbewahrungsnetz, Quick Connect, Plug 'n' Clean-System, Teleskopgriff, Wassergekühlter Motor, Integrierter Wasserfilter, Bluetooth-App-Verbindung",
#   'correct': False},
#  {'product': 'K 7 WCM Premium Home',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'The missing field "Preis (€ inkl. MwSt.)" for the product "K 7 WCM Premium Home" is 574.99 €.',
#   'ground_truth': '619.99',
#   'correct': False},
#  {'product': 'K 7 WCM Premium Home',
#   'field': 'Lieferzeit',
#   'llm_answer': 'The missing field "Lieferzeit" for the product "K 7 WCM Premium Home" is "2-3 Werktagen".',
#   'ground_truth': '2-3 Werktage',
#   'correct': False},
#  {'product': 'K 7 WCM Premium Home',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'The missing field "Stromart (V/Hz)" for the product "K 7 WCM Premium Home" is 230 / 50.',
#   'ground_truth': '230 / 50',
#   'correct': False},
#  {'product': 'K 7 WCM Premium Home',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'The missing field "Druck (bar/MPa)" for the product "K 7 WCM Premium Home" is 20 - max. 180 / 2 - max. 18.',
#   'ground_truth': '20 - max. 180 / 2 - max. 18',
#   'correct': False},
#  {'product': 'K 7 WCM Premium Home',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'The missing field "Fördermenge (l/h)" for the product "K 7 WCM Premium Home" is max. 600.',
#   'ground_truth': 'max. 600',
#   'correct': False},
#  {'product': 'K 7 WCM Premium Home',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'The missing field "Flächenleistung (m²/h)" for the product "K 7 WCM Premium Home" is 60.',
#   'ground_truth': '60',
#   'correct': False},
#  {'product': 'K 7 WCM Premium Home',
# ...
#   'ground_truth': 'max. 40',
#   'correct': False},
#  {'product': 'K 2 Premium Horizontal VPS Home',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'nicht angegeben',
#   'correct': False},
#  {'product': 'K 2 Premium Horizontal VPS Home',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'nicht angegeben',
#   'correct': False},
#  {'product': 'K 2 Premium Horizontal VPS Home',
#   'field': 'Farbe',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 2 Premium Horizontal VPS Home',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '3.5',
#   'correct': False},
#  {'product': 'K 2 Premium Horizontal VPS Home',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '7.2',
#   'correct': False},
#  {'product': 'K 2 Premium Horizontal VPS Home',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '380 x 197 x 264',
#   'correct': False},
#  {'product': 'K 2 Premium Horizontal VPS Home',
#   'field': 'Lieferumfang',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'Home Kit: Flächenreiniger T 1, Reinigungsmittel Patio & Deck 0,5 l, G 120 Q, Vario Power Jet, Dreckfräser, HD-Schlauch 4 m, Adapter Gartenschlauchanschluss A3/4"',
#   'correct': False},
#  {'product': 'K 2 Premium Horizontal VPS Home',
#   'field': 'Ausstattung',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'Geräteseitiges Quick Connect, Reinigungsmitteleinsatz über Ansaugschlauch, Integrierter Wasserfilter, Kabelaufwicklung',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'nicht verfügbar',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Lieferzeit',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'nicht verfügbar',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'Akku-Gerät / 36-V-Akkuplattform',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'max. 110',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '340',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'nicht angegeben',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'max. 40',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'nicht angegeben',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'nicht anwendbar',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Farbe',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '4.5',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '8.5',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '245 x 303 x 629',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Lieferumfang',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'Akku 36 V / 5,0 Ah Battery Power, Ladegerät 36 V Standard, G 120 Q Boost, 1-fach-Strahlrohr, Dreckfräser, HD-Schlauch 4 m, Adapter Gartenschlauchanschluss A3/4"',
#   'correct': False},
#  {'product': 'K 2 Battery Set',
#   'field': 'Ausstattung',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'Geräteseitiges Quick Connect, Reinigungsmitteleinsatz über Ansaugschlauch, Integrierter Wasserfilter, Integrierte Zubehöraufbewahrung',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '79.99',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Lieferzeit',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '3-4 Werktage',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '220 - 240 / 50 - 60',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '20 - max. 110',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'max. 360',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '20',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'max. 40',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '1.4',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Farbe',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '3.5',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '4.9',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '380 x 197 x 248',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Lieferumfang',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'G 120 Q, Vario Power Jet, Adapter Gartenschlauchanschluss A3/4"',
#   'correct': False},
#  {'product': 'K 2 Horizontal VPS',
#   'field': 'Ausstattung',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'Geräteseitiges Quick Connect, Reinigungsmitteleinsatz über Ansaugschlauch, Integrierter Wasserfilter, Kabelaufwicklung',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '142.49',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Lieferzeit',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '3-4 Werktage',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '220 - 240 / 50 - 60',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '20 - max. 110 / 2 - max. 11',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'max. 360',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '20',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'max. 40',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '1.4',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '5',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Farbe',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '4.0',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '6.7',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '246 x 280 x 586',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Lieferumfang',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'Home Kit: Flächenreiniger T 1, Reinigungsmittel Patio & Deck 0,5 l, G 120 Q, Vario Power Jet, Click Vario Power-Strahlohr, Dreckfräser, HD-Schlauch 5 m, Adapter Gartenschlauchanschluss A3/4"',
#   'correct': False},
#  {'product': 'K 2 Power Control Home',
#   'field': 'Ausstattung',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'Geräteseitiges Quick Connect, Reinigungsmitteleinsatz über Ansaugung, Teleskopgriff, Integrierter Wasserfilter',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '74.99',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Lieferzeit',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '3-4 Werktage',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '220 - 240 / 50 - 60',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '110 / 11',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'max. 360',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '20',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'max. 40',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '1.4',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'nicht angegeben',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Farbe',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'gelb',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Gewicht ohne Zubehör (kg)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '3.8',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Gewicht inkl. Verpackung (kg)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '4.6',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Abmessungen (L × B × H) (mm)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '182 x 280 x 390',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Lieferumfang',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'Hochdruckpistole: G 120 Q, Dreckfräser, HD-Schlauch: 3 m, Adapter Gartenschlauchanschluss A3/4"',
#   'correct': False},
#  {'product': 'K 2 Universal Edition',
#   'field': 'Ausstattung',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'Integrierter Wasserfilter',
#   'correct': False},
#  {'product': 'K 2 Universal Edition Home',
#   'field': 'Preis (€ inkl. MwSt.)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '104.99',
#   'correct': False},
#  {'product': 'K 2 Universal Edition Home',
#   'field': 'Lieferzeit',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '3-4 Werktage',
#   'correct': False},
#  {'product': 'K 2 Universal Edition Home',
#   'field': 'Stromart (V/Hz)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '220 - 240 / 50 - 60',
#   'correct': False},
#  {'product': 'K 2 Universal Edition Home',
#   'field': 'Druck (bar/MPa)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '110 / 11',
#   'correct': False},
#  {'product': 'K 2 Universal Edition Home',
#   'field': 'Fördermenge (l/h)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'max. 360',
#   'correct': False},
#  {'product': 'K 2 Universal Edition Home',
#   'field': 'Flächenleistung (m²/h)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '20',
#   'correct': False},
#  {'product': 'K 2 Universal Edition Home',
#   'field': 'Zulauftemperatur (°C)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'max. 40',
#   'correct': False},
#  {'product': 'K 2 Universal Edition Home',
#   'field': 'Anschlussleistung (kW)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': '1.4',
#   'correct': False},
#  {'product': 'K 2 Universal Edition Home',
#   'field': 'Anschlusskabel (m)',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'nicht angegeben',
#   'correct': False},
#  {'product': 'K 2 Universal Edition Home',
#   'field': 'Farbe',
#   'llm_answer': 'No documentation found mentioning this product.',
#   'ground_truth': 'gelb',
#   'correct': False},
#  ...]

# %%
results_df = pd.DataFrame(results)
accuracy = results_df["correct"].mean()
print(f"Overall Accuracy: {accuracy:.2%}")
# Out:
# Overall Accuracy: 0.00%
